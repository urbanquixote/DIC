# %% [markdown]
# # 04-Time Series Forecasting: Tutorial 2
#
# ### - ARIMA
# ### - Seasonal ARIMA (SARIMA)
# ### - Prophet

# %% [markdown]
# ### 1. 모듈 불러오기

# %%
# !pip install pmdarima

import os
import datetime
import itertools
import warnings
warnings.filterwarnings(action='ignore') 

import numpy as np
import pandas as pd
import pandas_datareader as pdr

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import matplotlib.pyplot as plt
import matplotlib
plt.style.use('seaborn-whitegrid')
import seaborn as sns

import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX 
from pmdarima.arima import auto_arima
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from prophet import Prophet

# !git clone https://github.com/hansam95/LG-Elec-Day3.git
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# ### 2. 데이터 불러오기

# %%
# 월별 비행기 탑승객 데이터
# data = pd.read_csv('./data/AirPassengers.csv')
data = pd.read_csv('/content/LG-Elec-Day3/data/AirPassengers.csv')
data = data.rename(columns={'Month': 'month', '#Passengers': 'passengers'})
data['month'] = pd.to_datetime(data['month'])
data = data.set_index('month')
data
# Out:
#             passengers
# month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %% [markdown]
# ### 3. Box-Jenkins ARIMA Procedure
# -  3.1 Data Preprocessing
# -  3.2 Identify Model to be Tentatively Entertainted
# -  3.3 Estimate Parameters
# -  3.4 Diagnosis Check
# -  3.5 use Model to Forecast

# %% [markdown]
# <img src='./image/img11.png' width='800'></img>

# %% [markdown]
# #### 3.1 Data Preprocessing

# %%
'''
데이터 시각화를 통해 전체 개요 확인
'''
data.plot(figsize=(12,4)) # color='green', linestyle='--', linewidth=1

plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.legend('')

plt.title('Passenger Data \n', fontsize=15)
plt.xlabel('\n Year', fontsize=13)
plt.ylabel('Passenger \n', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Seasonal decomposition plot: Seasonal decomposition using moving averages.
# https://www.statsmodels.org/stable/generated/statsmodels.tsa.seasonal.seasonal_decompose.html

# Observed: observed data
# Trend: The estimated trend component
# Seasonal: The estimated seasonal component
# resid: The estimated residuals

decomposition = sm.tsa.seasonal_decompose(data['passengers'],  model='additive')

fig = decomposition.plot()
fig.set_size_inches(10,10)
plt.show()

# %% [markdown]
# #### 3.2 Identify Model to be Tentatively Entertainted

# %%
# Train:Test = 8:2
train, test = train_test_split(data, test_size=0.2, shuffle=False)

# %%
train.tail()
# Out:
#             passengers
# month
# 1958-03-01         362
# 1958-04-01         348
# 1958-05-01         363
# 1958-06-01         435
# 1958-07-01         491

# %%
test.head()
# Out:
#             passengers
# month
# 1958-08-01         505
# 1958-09-01         404
# 1958-10-01         359
# 1958-11-01         310
# 1958-12-01         337

# %%
# ACF, PACF plot 

# https://www.statsmodels.org/stable/generated/statsmodels.graphics.tsaplots.plot_acf.html
# https://www.statsmodels.org/stable/generated/statsmodels.graphics.tsaplots.plot_pacf.html

fig, ax = plt.subplots(1,2,figsize=(10,5))
fig.suptitle('Raw Data')
sm.graphics.tsa.plot_acf(train.values.squeeze(), lags=30, ax=ax[0])
sm.graphics.tsa.plot_pacf(train.values.squeeze(), lags=30, ax=ax[1]); # Modify not to generate graph twice
# ACF 0으로 빠르게 수렴하지 않음 -> 정상성 만족 X

# %%
# Differencing

diff_train = train.copy()
# 1차차분 값 계산
diff_train = diff_train['passengers'].diff()
diff_train = diff_train.dropna()
print('####### Raw Data #######')
print(train)
print('### Differenced Data ###')
print(diff_train)
# Out:
# ####### Raw Data #######
#             passengers
# month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1958-03-01         362
# 1958-04-01         348
# 1958-05-01         363
# 1958-06-01         435
# 1958-07-01         491
#
# [115 rows x 1 columns]
# ### Differenced Data ###
# month
# 1949-02-01     6.0
# 1949-03-01    14.0
# 1949-04-01    -3.0
# 1949-05-01    -8.0
# 1949-06-01    14.0
#               ...
# 1958-03-01    44.0
# 1958-04-01   -14.0
# 1958-05-01    15.0
# 1958-06-01    72.0
# 1958-07-01    56.0
# Name: passengers, Length: 114, dtype: float64

# %%
# Differenced data plot

plt.figure(figsize=(12,8))
plt.subplot(211)
plt.plot(train['passengers'])
plt.legend(['Raw Data (Nonstationary)'])
plt.subplot(212)
plt.plot(diff_train,'orange') # first difference (t - (t-1))
plt.legend(['Differenced Data (Stationary)'])
plt.show()

# %%
# ACF, PACF plot 

fig, ax = plt.subplots(1,2,figsize=(10,5))
fig.suptitle('Differenced Data')
sm.graphics.tsa.plot_acf(diff_train.values.squeeze(), lags=30, ax=ax[0])
sm.graphics.tsa.plot_pacf(diff_train.values.squeeze(), lags=30, ax=ax[1]); # Modify not to generate graph twice

# %% [markdown]
# #### 3.3 Estimate Parameters

# %%
# ARIMA model fitting
# The (p,d,q) order of the model for the number of AR parameters, differences, and MA parameters to use.

ARIMA_model = ARIMA(train.values, order=(1,1,0))
ARIMA_model_fit = ARIMA_model.fit()
ARIMA_model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  115
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                -532.268
# Date:                Wed, 08 Feb 2023   AIC                           1068.536
# Time:                        17:03:27   BIC                           1074.008
# Sample:                             0   HQIC                          1070.757
#                                 - 115
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2904      0.089      3.278      0.001       0.117       0.464
# sigma2       664.7320     89.253      7.448      0.000     489.800     839.664
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.32   Jarque-Bera (JB):                 3.25
# Prob(Q):                              0.57   Prob(JB):                         0.20
# Heteroskedasticity (H):               6.18   Skew:                             0.40
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# #### 3.4.1 Diagnosis Check - ARIMA

# %%
# Parameter search 

print('Examples of parameter combinations for ARIMA...')
p = range(0, 3)
d = range(1, 2)
q = range(0, 3)
pdq = list(itertools.product(p, d, q))

aic_all=[]
for i in pdq:
    model = ARIMA(train.values, order=(i))
    ARIMA_model_fit = model.fit()
    print(f'ARIMA: {i} >> AIC : {round(ARIMA_model_fit.aic,2)}')
    aic_all.append(round(ARIMA_model_fit.aic,2))
# Out:
# Examples of parameter combinations for ARIMA...
# ARIMA: (0, 1, 0) >> AIC : 1076.27
# ARIMA: (0, 1, 1) >> AIC : 1063.65
# ARIMA: (0, 1, 2) >> AIC : 1060.69
# ARIMA: (1, 1, 0) >> AIC : 1068.54
# ARIMA: (1, 1, 1) >> AIC : 1058.25
# ARIMA: (1, 1, 2) >> AIC : 1057.33
# ARIMA: (2, 1, 0) >> AIC : 1065.64
# ARIMA: (2, 1, 1) >> AIC : 1058.65
# ARIMA: (2, 1, 2) >> AIC : 1057.52

# %%
# Search optimal parameters
# AIC은 낮을수록 좋은 값 / AIC 기준으로 best (p,d,q) 찾기
for i, aic in enumerate(aic_all):
    if aic == min(aic_all):
        ARIMA_optimal = [(pdq[i], aic)]

ARIMA_optimal
# Out:
# [((1, 1, 2), 1057.33)]

# %%
ARIMA_model_opt = ARIMA(train.values, order=ARIMA_optimal[0][0])
ARIMA_model_opt_fit = ARIMA_model_opt.fit()

ARIMA_model_opt_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  115
# Model:                 ARIMA(1, 1, 2)   Log Likelihood                -524.664
# Date:                Wed, 08 Feb 2023   AIC                           1057.328
# Time:                        17:03:28   BIC                           1068.272
# Sample:                             0   HQIC                          1061.769
#                                 - 115
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5387      0.128      4.219      0.000       0.288       0.789
# ma.L1         -0.2053      0.122     -1.688      0.091      -0.444       0.033
# ma.L2         -0.5606      0.084     -6.647      0.000      -0.726      -0.395
# sigma2       578.5728    105.827      5.467      0.000     371.155     785.991
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.52   Jarque-Bera (JB):                 4.81
# Prob(Q):                              0.47   Prob(JB):                         0.09
# Heteroskedasticity (H):               5.54   Skew:                             0.18
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# #### 3.5.1 use Model to Forecast - ARIMA

# %%
ARIMA_prediction = ARIMA_model_opt_fit.get_forecast(len(test)).summary_frame()
ARIMA_prediction.head()
# Out:
# y        mean    mean_se  mean_ci_lower  mean_ci_upper
# 0  482.493841  24.053540     435.349770     529.637912
# 1  450.831653  40.090316     372.256078     529.407228
# 2  433.775780  46.173568     343.277249     524.274312
# 3  424.588076  49.547407     327.476944     521.699209
# 4  419.638819  51.859228     317.996599     521.281039

# %%
ARIMA_test_pred = ARIMA_prediction['mean']
ARIMA_test_ub = ARIMA_prediction['mean_ci_upper']
ARIMA_test_lb = ARIMA_prediction['mean_ci_lower']
predict_index = list(test.index)

# %%
'''
Quantitative Evaluation
'''
print('ARIMA')
print('-'*30)
print(f'MSE: {np.round(mean_squared_error(test, ARIMA_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,ARIMA_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, ARIMA_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, ARIMA_test_pred), 2)}')
# Out:
# ARIMA
# ------------------------------
# MSE: 6828.67
# RMSE: 82.64
# MAE: 62.06
# R2 score: -0.12

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(data.index, data.values, label = 'Passengers')
ax.vlines(datetime.datetime.strptime('1958-08-01','%Y-%m-%d'), 0, 800, linestyle='--', color='r', label='Start of Forecast')
ax.plot(predict_index, ARIMA_test_pred, label = 'Prediction')
ax.fill_between(predict_index, ARIMA_test_lb, ARIMA_test_ub, color = 'k', alpha = 0.1, label='0.95 Prediction Interval')
ax.legend(loc='upper left')
plt.suptitle(f'ARIMA {ARIMA_optimal[0][0]} Prediction Results (r2_score: {np.round(r2_score(test, ARIMA_test_pred), 2)}')
plt.show()

# %% [markdown]
# #### 3.4.2 Diagnosis Check - SARIMA

# %%
# Parameter search

print('Examples of parameter combinations for Seasonal ARIMA...')
p = range(0, 3)
d = range(1, 2)
q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

aic=[]
params=[]
for i in pdq:
    for j in seasonal_pdq:
        try:
            model = SARIMAX(train.values, order=(i), seasonal_order = (j))
            model_fit = model.fit()
            print(f'SARIMA: {i}{j} >> AIC : {round(model_fit.aic,2)}')
            aic.append(round(model_fit.aic,2))
            params.append((i, j))  
        except:
            continue
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMA: (0, 1, 0)(0, 1, 0, 12) >> AIC : 757.83
# SARIMA: (0, 1, 0)(0, 1, 1, 12) >> AIC : 756.99
# SARIMA: (0, 1, 0)(0, 1, 2, 12) >> AIC : 758.83
# SARIMA: (0, 1, 0)(1, 1, 0, 12) >> AIC : 756.96
# SARIMA: (0, 1, 0)(1, 1, 1, 12) >> AIC : 758.92
# SARIMA: (0, 1, 0)(1, 1, 2, 12) >> AIC : 754.42
# SARIMA: (0, 1, 0)(2, 1, 0, 12) >> AIC : 758.87
# SARIMA: (0, 1, 0)(2, 1, 1, 12) >> AIC : 760.73
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.28952D+00    |proj g|=  1.22026D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      4      5      1     0     0   1.996D-06   3.286D+00
#   F =   3.2861996629492620
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27511D+00    |proj g|=  3.00947D-02
#
# At iterate    5    f=  3.27408D+00    |proj g|=  1.41940D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      9     11      1     0     0   1.984D-06   3.274D+00
#   F =   3.2738615787519612
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.54784D+00    |proj g|=  7.91692D-02
#
# At iterate    5    f=  3.39266D+00    |proj g|=  2.26125D-01
#
# At iterate   10    f=  3.27780D+00    |proj g|=  8.74964D-02
#
# At iterate   15    f=  3.27316D+00    |proj g|=  1.24321D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     15     22      1     0     0   1.243D-05   3.273D+00
#   F =   3.2731562923053170
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27500D+00    |proj g|=  1.12854D-02
#
# At iterate    5    f=  3.27379D+00    |proj g|=  9.15895D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      8     10      1     0     0   1.712D-06   3.274D+00
#   F =   3.2737354957243898
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27538D+00    |proj g|=  3.09739D-02
#
# At iterate    5    f=  3.27403D+00    |proj g|=  2.01981D-02
#
# At iterate   10    f=  3.27360D+00    |proj g|=  3.26758D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     14     16      1     0     0   3.917D-06   3.274D+00
#   F =   3.2735733279077568
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.51204D+00    |proj g|=  2.05113D-01
#
# At iterate    5    f=  3.28595D+00    |proj g|=  2.88808D-02
#
# At iterate   10    f=  3.25877D+00    |proj g|=  1.76150D-02
#
# At iterate   15    f=  3.24562D+00    |proj g|=  4.27816D-04
#
# At iterate   20    f=  3.24549D+00    |proj g|=  1.07617D-03
#
# At iterate   25    f=  3.24536D+00    |proj g|=  4.23268D-04
#
# At iterate   30    f=  3.24532D+00    |proj g|=  1.52835D-04
#
# At iterate   35    f=  3.24531D+00    |proj g|=  9.06901D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     38     50      1     0     0   1.792D-05   3.245D+00
#   F =   3.2453141633396791
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27587D+00    |proj g|=  9.18432D-03
#
# At iterate    5    f=  3.27335D+00    |proj g|=  2.73366D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7     10      1     0     0   2.962D-06   3.273D+00
#   F =   3.2733425476086020
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27567D+00    |proj g|=  3.53554D-02
#
# At iterate    5    f=  3.27418D+00    |proj g|=  9.79361D-03
#
# At iterate   10    f=  3.27373D+00    |proj g|=  2.64087D-04
#
# At iterate   15    f=  3.27363D+00    |proj g|=  1.08730D-02
#
# At iterate   20    f=  3.27272D+00    |proj g|=  1.81869D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     24     31      1     0     0   3.729D-06   3.273D+00
#   F =   3.2727209518853946
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.51351D+00    |proj g|=  4.93570D-01
#
# At iterate    5    f=  3.29230D+00    |proj g|=  2.38883D-02
#
# At iterate   10    f=  3.28331D+00    |proj g|=  5.13752D-03
#
# At iterate   15    f=  3.25741D+00    |proj g|=  9.35019D-02
#
# At iterate   20    f=  3.24276D+00    |proj g|=  4.05237D-02
#
# At iterate   25    f=  3.23922D+00    |proj g|=  2.18114D-03
# /usr/local/lib/python3.8/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# SARIMA: (0, 1, 0)(2, 1, 2, 12) >> AIC : 754.9
# SARIMA: (0, 1, 1)(0, 1, 0, 12) >> AIC : 756.01
# SARIMA: (0, 1, 1)(0, 1, 1, 12) >> AIC : 756.38
# SARIMA: (0, 1, 1)(0, 1, 2, 12) >> AIC : 757.65
# SARIMA: (0, 1, 1)(1, 1, 0, 12) >> AIC : 756.17
# SARIMA: (0, 1, 1)(1, 1, 1, 12) >> AIC : 758.11
# SARIMA: (0, 1, 1)(1, 1, 2, 12) >> AIC : 751.73
# SARIMA: (0, 1, 1)(2, 1, 0, 12) >> AIC : 757.99
# At iterate   30    f=  3.23889D+00    |proj g|=  2.01459D-03
#
# At iterate   35    f=  3.23886D+00    |proj g|=  6.87843D-05
#
# At iterate   40    f=  3.23886D+00    |proj g|=  2.51418D-05
#
# At iterate   45    f=  3.23885D+00    |proj g|=  1.63797D-04
#
# At iterate   50    f=  3.23870D+00    |proj g|=  2.72263D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     65      1     0     0   2.723D-03   3.239D+00
#   F =   3.2387042572134042
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27015D+00    |proj g|=  1.22280D-02
#
# At iterate    5    f=  3.26962D+00    |proj g|=  2.43220D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7      9      1     0     0   4.492D-06   3.270D+00
#   F =   3.2696145681940023
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26350D+00    |proj g|=  1.25886D-02
#
# At iterate    5    f=  3.26253D+00    |proj g|=  3.25272D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      8     10      1     0     0   6.350D-06   3.263D+00
#   F =   3.2625229644049796
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.51240D+00    |proj g|=  2.92669D-01
#
# At iterate    5    f=  3.34689D+00    |proj g|=  1.82375D-01
#
# At iterate   10    f=  3.27993D+00    |proj g|=  6.62301D-02
#
# At iterate   15    f=  3.25936D+00    |proj g|=  3.16271D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     17     24      1     0     0   2.212D-06   3.259D+00
#   F =   3.2593610058082612
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26337D+00    |proj g|=  3.44429D-02
#
# At iterate    5    f=  3.26185D+00    |proj g|=  1.43551D-02
#
# At iterate   10    f=  3.26159D+00    |proj g|=  4.27969D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     10     12      1     0     0   4.280D-07   3.262D+00
#   F =   3.2615894604296916
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26437D+00    |proj g|=  1.95529D-02
#
# At iterate    5    f=  3.26164D+00    |proj g|=  1.66720D-02
#
# At iterate   10    f=  3.26133D+00    |proj g|=  8.81088D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     17      1     0     0   3.371D-06   3.261D+00
#   F =   3.2613342475460212
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.46502D+00    |proj g|=  2.26634D-01
#
# At iterate    5    f=  3.32481D+00    |proj g|=  9.60158D-02
#
# At iterate   10    f=  3.26403D+00    |proj g|=  1.71337D-02
#
# At iterate   15    f=  3.22512D+00    |proj g|=  5.01775D-03
#
# At iterate   20    f=  3.22499D+00    |proj g|=  4.87753D-04
#
# At iterate   25    f=  3.22499D+00    |proj g|=  2.24810D-04
#
# At iterate   30    f=  3.22497D+00    |proj g|=  1.93365D-03
#
# At iterate   35    f=  3.22493D+00    |proj g|=  6.69842D-04
#
# At iterate   40    f=  3.22491D+00    |proj g|=  4.61105D-04
#
# At iterate   45    f=  3.22491D+00    |proj g|=  1.64228D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     46     65      1     0     0   1.648D-04   3.225D+00
#   F =   3.2249061527552425
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26426D+00    |proj g|=  5.73406D-02
#
# At iterate    5    f=  3.26123D+00    |proj g|=  9.81612D-03
#
# At iterate   10    f=  3.26084D+00    |proj g|=  9.50307D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     10     13      1     0     0   9.503D-07   3.261D+00
#   F =   3.2608449503391053
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26534D+00    |proj g|=  8.52494D-02
#
# At iterate    5    f=  3.25911D+00    |proj g|=  2.11458D-02
#
# At iterate   10    f=  3.24283D+00    |proj g|=  1.22084D-02
#
# At iterate   15    f=  3.23573D+00    |proj g|=  5.63056D-03
#
# SARIMA: (0, 1, 1)(2, 1, 1, 12) >> AIC : 753.78
# SARIMA: (0, 1, 2)(0, 1, 0, 12) >> AIC : 757.78
# SARIMA: (0, 1, 2)(0, 1, 1, 12) >> AIC : 758.04
# SARIMA: (0, 1, 2)(0, 1, 2, 12) >> AIC : 759.28
# SARIMA: (0, 1, 2)(1, 1, 0, 12) >> AIC : 757.81
# SARIMA: (0, 1, 2)(1, 1, 1, 12) >> AIC : 759.75
# SARIMA: (0, 1, 2)(1, 1, 2, 12) >> AIC : 753.5
# At iterate   20    f=  3.23427D+00    |proj g|=  8.69316D-04
#
# At iterate   25    f=  3.23399D+00    |proj g|=  2.54401D-03
#
# At iterate   30    f=  3.23386D+00    |proj g|=  1.41580D-04
#
# At iterate   35    f=  3.23385D+00    |proj g|=  2.72766D-04
#
# At iterate   40    f=  3.23385D+00    |proj g|=  6.88992D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     40     56      1     0     0   6.890D-04   3.234D+00
#   F =   3.2338463049745187
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.46597D+00    |proj g|=  4.11139D-01
#
# At iterate    5    f=  3.27482D+00    |proj g|=  3.17061D-02
#
# At iterate   10    f=  3.26456D+00    |proj g|=  9.26426D-03
#   ys=-2.774E+06  -gs= 5.298E-02 BFGS update SKIPPED
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27137D+00    |proj g|=  6.20563D-02
#
# At iterate    5    f=  3.26898D+00    |proj g|=  5.78718D-03
#
# At iterate   10    f=  3.26860D+00    |proj g|=  2.17328D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     10     12      1     0     0   2.173D-06   3.269D+00
#   F =   3.2685992822824717
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26516D+00    |proj g|=  6.12507D-02
#
# At iterate    5    f=  3.26160D+00    |proj g|=  1.10075D-02
#
# At iterate   10    f=  3.26105D+00    |proj g|=  7.51422D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     11     14      1     0     0   1.476D-06   3.261D+00
#   F =   3.2610547634986657
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.52595D+00    |proj g|=  3.74498D-01
#
# At iterate    5    f=  3.45783D+00    |proj g|=  3.21052D-02
#
# At iterate   10    f=  3.29977D+00    |proj g|=  3.80189D-02
#
# At iterate   15    f=  3.25779D+00    |proj g|=  4.65314D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     19     25      1     0     0   4.240D-06   3.258D+00
#   F =   3.2577561783433646
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26479D+00    |proj g|=  6.33895D-02
#
# At iterate    5    f=  3.26065D+00    |proj g|=  1.52103D-02
#
# At iterate   10    f=  3.26005D+00    |proj g|=  7.47986D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     11     14      1     0     0   1.723D-06   3.260D+00
#   F =   3.2600473290194745
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26620D+00    |proj g|=  6.45071D-02
#
# At iterate    5    f=  3.26096D+00    |proj g|=  2.53945D-02
#
# At iterate   10    f=  3.25979D+00    |proj g|=  1.89163D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     11     13      1     0     0   1.863D-05   3.260D+00
#   F =   3.2597852906694071
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.47644D+00    |proj g|=  3.00967D-01
#
# At iterate    5    f=  3.29666D+00    |proj g|=  5.57696D-02
#
# At iterate   10    f=  3.22840D+00    |proj g|=  3.43502D-02
#
# At iterate   15    f=  3.22397D+00    |proj g|=  3.97577D-03
#
# At iterate   20    f=  3.22395D+00    |proj g|=  3.96341D-05
#
# At iterate   25    f=  3.22395D+00    |proj g|=  1.33107D-03
#
# At iterate   30    f=  3.22393D+00    |proj g|=  5.29983D-04
#
# At iterate   35    f=  3.22391D+00    |proj g|=  6.98425D-04
#
# At iterate   40    f=  3.22390D+00    |proj g|=  1.21199D-03
#   ys=-6.755E-06  -gs= 1.174E-06 BFGS update SKIPPED
#
# At iterate   45    f=  3.22389D+00    |proj g|=  6.16638D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     47     65      1     1     0   1.666D-04   3.224D+00
#   F =   3.2238947097539410
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26626D+00    |proj g|=  7.47640D-02
#
# At iterate    5    f=  3.25983D+00    |proj g|=  9.27909D-03
#
# At iterate   10    f=  3.25931D+00    |proj g|=  2.71797D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# SARIMA: (0, 1, 2)(2, 1, 0, 12) >> AIC : 759.64
# SARIMA: (0, 1, 2)(2, 1, 1, 12) >> AIC : 755.49
# SARIMA: (0, 1, 2)(2, 1, 2, 12) >> AIC : 99.0
# SARIMA: (1, 1, 0)(0, 1, 0, 12) >> AIC : 755.5
# SARIMA: (1, 1, 0)(0, 1, 1, 12) >> AIC : 755.98
# SARIMA: (1, 1, 0)(0, 1, 2, 12) >> AIC : 757.1
# SARIMA: (1, 1, 0)(1, 1, 0, 12) >> AIC : 755.75
# SARIMA: (1, 1, 0)(1, 1, 1, 12) >> AIC : 757.65
#     5     11     14      1     0     0   2.577D-07   3.259D+00
#   F =   3.2593099540426804
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26738D+00    |proj g|=  1.02219D-01
#
# At iterate    5    f=  3.25821D+00    |proj g|=  1.25174D-02
#
# At iterate   10    f=  3.24370D+00    |proj g|=  1.64800D-02
#
# At iterate   15    f=  3.23640D+00    |proj g|=  3.29332D-02
#
# At iterate   20    f=  3.23389D+00    |proj g|=  1.03444D-02
#
# At iterate   25    f=  3.23293D+00    |proj g|=  3.52571D-03
#
# At iterate   30    f=  3.23270D+00    |proj g|=  4.44262D-03
#
# At iterate   35    f=  3.23258D+00    |proj g|=  2.62348D-03
#
# At iterate   40    f=  3.23255D+00    |proj g|=  9.78858D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     41     54      1     0     0   9.801D-04   3.233D+00
#   F =   3.2325471073059218
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.47741D+00    |proj g|=  4.29506D-01
#
# At iterate    5    f=  3.27636D+00    |proj g|=  3.07844D-02
#
# At iterate   10    f=  3.26368D+00    |proj g|=  4.76912D-03
#
# At iterate   15    f=  3.26289D+00    |proj g|=  2.77520D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     19     42      1     0     0   9.407D+04   3.696D-01
#   F =  0.36958156141383514
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26740D+00    |proj g|=  1.30394D-03
#
# At iterate    5    f=  3.26739D+00    |proj g|=  1.18637D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      8     10      1     0     0   5.870D-07   3.267D+00
#   F =   3.2673885458939407
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26142D+00    |proj g|=  2.61787D-02
#
# At iterate    5    f=  3.26085D+00    |proj g|=  3.56672D-03
#
# At iterate   10    f=  3.26079D+00    |proj g|=  3.27134D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     10     12      1     0     0   3.271D-06   3.261D+00
#   F =   3.2607893084154318
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.52942D+00    |proj g|=  3.28067D-01
#
# At iterate    5    f=  3.36758D+00    |proj g|=  1.44222D-01
#
# At iterate   10    f=  3.25903D+00    |proj g|=  3.98618D-02
#
# At iterate   15    f=  3.25697D+00    |proj g|=  3.34061D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     16     23      1     0     0   5.582D-06   3.257D+00
#   F =   3.2569715221152582
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26128D+00    |proj g|=  3.98758D-02
#
# At iterate    5    f=  3.25979D+00    |proj g|=  2.63530D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      8     10      1     0     0   5.509D-07   3.260D+00
#   F =   3.2597837869743165
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26246D+00    |proj g|=  2.94278D-02
#
# At iterate    5    f=  3.26050D+00    |proj g|=  2.32980D-02
#
# At iterate   10    f=  3.25934D+00    |proj g|=  6.86909D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     12     15      1     0     0   1.628D-05   3.259D+00
#   F =   3.2593421276650445
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.47712D+00    |proj g|=  2.57456D-01
#
# At iterate    5    f=  3.30809D+00    |proj g|=  9.97289D-02
#
# At iterate   10    f=  3.22686D+00    |proj g|=  4.26021D-02
#
# At iterate   15    f=  3.22250D+00    |proj g|=  1.97304D-03
#
# At iterate   20    f=  3.22246D+00    |proj g|=  1.23568D-04
#
# At iterate   25    f=  3.22244D+00    |proj g|=  9.26561D-04
#
# At iterate   30    f=  3.22240D+00    |proj g|=  9.99259D-04
#
# At iterate   35    f=  3.22239D+00    |proj g|=  4.33407D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     39     55      1     0     0   4.908D-05   3.222D+00
# SARIMA: (1, 1, 0)(1, 1, 2, 12) >> AIC : 751.15
# SARIMA: (1, 1, 0)(2, 1, 0, 12) >> AIC : 757.45
# SARIMA: (1, 1, 0)(2, 1, 1, 12) >> AIC : 752.98
# SARIMA: (1, 1, 1)(0, 1, 0, 12) >> AIC : 756.02
# SARIMA: (1, 1, 1)(0, 1, 1, 12) >> AIC : 756.63
# SARIMA: (1, 1, 1)(0, 1, 2, 12) >> AIC : 757.75
# SARIMA: (1, 1, 1)(1, 1, 0, 12) >> AIC : 756.41
# SARIMA: (1, 1, 1)(1, 1, 1, 12) >> AIC : 758.26
#   F =   3.2223876754314098
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26260D+00    |proj g|=  7.39403D-02
#
# At iterate    5    f=  3.25861D+00    |proj g|=  2.85218D-03
#
# At iterate   10    f=  3.25849D+00    |proj g|=  3.89022D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     10     12      1     0     0   3.890D-08   3.258D+00
#   F =   3.2584922591459606
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26364D+00    |proj g|=  1.01795D-01
#
# At iterate    5    f=  3.25588D+00    |proj g|=  1.59909D-02
#
# At iterate   10    f=  3.23577D+00    |proj g|=  1.27614D-02
#
# At iterate   15    f=  3.23190D+00    |proj g|=  4.47618D-03
#
# At iterate   20    f=  3.23068D+00    |proj g|=  4.70772D-03
#
# At iterate   25    f=  3.23045D+00    |proj g|=  1.39458D-03
#
# At iterate   30    f=  3.23039D+00    |proj g|=  6.60417D-04
#
# At iterate   35    f=  3.23037D+00    |proj g|=  1.25542D-03
#
# At iterate   40    f=  3.23035D+00    |proj g|=  6.78920D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     43     70      1     0     0   7.249D-05   3.230D+00
#   F =   3.2303528571111428
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.47820D+00    |proj g|=  4.36854D-01
#
# At iterate    5    f=  3.27015D+00    |proj g|=  2.87989D-02
#
# At iterate   10    f=  3.26204D+00    |proj g|=  3.12926D-03
#
# At iterate   15    f=  3.25638D+00    |proj g|=  3.79819D-02
#
# At iterate   20    f=  3.25592D+00    |proj g|=  6.29034D-02
#   ys=-2.635E-04  -gs= 4.663E-04 BFGS update SKIPPED
#
# At iterate   25    f=  3.25456D+00    |proj g|=  8.40363D-02
#   ys=-2.911E-05  -gs= 9.618E-06 BFGS update SKIPPED
#
# At iterate   30    f=  3.25323D+00    |proj g|=  5.11297D-02
#
# At iterate   35    f= -0.00000D+00    |proj g|=  7.97348D+04
#   ys=-1.182E+06  -gs= 3.481E+00 BFGS update SKIPPED
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26736D+00    |proj g|=  1.65570D-02
#
# At iterate    5    f=  3.26099D+00    |proj g|=  1.72008D-03
#
# At iterate   10    f=  3.26097D+00    |proj g|=  5.55234D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     12     15      1     0     0   6.964D-06   3.261D+00
#   F =   3.2609650556335654
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26183D+00    |proj g|=  2.06734D-02
#
# At iterate    5    f=  3.25600D+00    |proj g|=  2.38288D-02
#
# At iterate   10    f=  3.25491D+00    |proj g|=  3.47583D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     16      1     0     0   3.298D-06   3.255D+00
#   F =   3.2549065910326695
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.52054D+00    |proj g|=  1.34107D-01
#
# At iterate    5    f=  3.31825D+00    |proj g|=  8.66928D-02
#
# At iterate   10    f=  3.26403D+00    |proj g|=  4.23931D-02
#
# At iterate   15    f=  3.25290D+00    |proj g|=  3.73644D-02
#
# At iterate   20    f=  3.25109D+00    |proj g|=  2.41527D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     23     33      1     0     0   3.676D-06   3.251D+00
#   F =   3.2510810948245772
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26193D+00    |proj g|=  4.31497D-02
#
# At iterate    5    f=  3.25568D+00    |proj g|=  4.16792D-02
#
# At iterate   10    f=  3.25394D+00    |proj g|=  3.14211D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     17      1     0     0   1.306D-07   3.254D+00
#   F =   3.2539374376867327
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26280D+00    |proj g|=  3.09266D-02
#
# At iterate    5    f=  3.25399D+00    |proj g|=  2.63147D-02
#
# At iterate   10    f=  3.25331D+00    |proj g|=  2.35052D-04
#
# At iterate   15    f=  3.25331D+00    |proj g|=  6.40842D-05
#
# At iterate   20    f=  3.25331D+00    |proj g|=  8.53343D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     20     25      1     0     0   8.533D-05   3.253D+00
#   F =   3.2533052199102412
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
# /usr/local/lib/python3.8/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# SARIMA: (1, 1, 1)(1, 1, 2, 12) >> AIC : 752.53
# SARIMA: (1, 1, 1)(2, 1, 0, 12) >> AIC : 758.03
# /usr/local/lib/python3.8/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# SARIMA: (1, 1, 1)(2, 1, 1, 12) >> AIC : 754.16
# SARIMA: (1, 1, 1)(2, 1, 2, 12) >> AIC : 760.17
# SARIMA: (1, 1, 2)(0, 1, 0, 12) >> AIC : 757.92
# SARIMA: (1, 1, 2)(0, 1, 1, 12) >> AIC : 758.44
# SARIMA: (1, 1, 2)(0, 1, 2, 12) >> AIC : 759.63
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.46960D+00    |proj g|=  2.31984D-01
#
# At iterate    5    f=  3.28215D+00    |proj g|=  2.20763D-02
#
# At iterate   10    f=  3.24037D+00    |proj g|=  5.81855D-02
#
# At iterate   15    f=  3.22094D+00    |proj g|=  5.77789D-03
#
# At iterate   20    f=  3.21985D+00    |proj g|=  4.47193D-04
#
# At iterate   25    f=  3.21985D+00    |proj g|=  4.54667D-04
#
# At iterate   30    f=  3.21983D+00    |proj g|=  1.82549D-03
#
# At iterate   35    f=  3.21975D+00    |proj g|=  5.86841D-04
#
# At iterate   40    f=  3.21972D+00    |proj g|=  3.06099D-04
#
# At iterate   45    f=  3.21971D+00    |proj g|=  2.90667D-04
#
# At iterate   50    f=  3.21970D+00    |proj g|=  2.88921D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     50     68      1     0     0   2.889D-04   3.220D+00
#   F =   3.2197014660886016
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26321D+00    |proj g|=  7.51026D-02
#
# At iterate    5    f=  3.25234D+00    |proj g|=  3.92895D-03
#
# At iterate   10    f=  3.25231D+00    |proj g|=  3.24445D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     13     18      1     0     0   1.741D-05   3.252D+00
#   F =   3.2523066245439081
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26393D+00    |proj g|=  9.66979D-02
#
# At iterate    5    f=  3.25122D+00    |proj g|=  2.61856D-02
#
# At iterate   10    f=  3.23479D+00    |proj g|=  2.79999D-02
#
# At iterate   15    f=  3.22919D+00    |proj g|=  1.67806D-02
#
# At iterate   20    f=  3.22743D+00    |proj g|=  4.46655D-03
#
# At iterate   25    f=  3.22698D+00    |proj g|=  8.26883D-04
#
# At iterate   30    f=  3.22686D+00    |proj g|=  1.99758D-03
#
# At iterate   35    f=  3.22681D+00    |proj g|=  8.11349D-04
#
# At iterate   40    f=  3.22681D+00    |proj g|=  1.13831D-03
#
# At iterate   45    f=  3.22680D+00    |proj g|=  7.43686D-04
#
# At iterate   50    f=  3.22680D+00    |proj g|=  1.57952D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     50     90      1     0     0   1.580D-04   3.227D+00
#   F =   3.2268021618652774
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.47062D+00    |proj g|=  4.30521D-01
#
# At iterate    5    f=  3.26405D+00    |proj g|=  1.78104D-02
#
# At iterate   10    f=  3.25599D+00    |proj g|=  1.83507D-03
#
# At iterate   15    f=  3.25437D+00    |proj g|=  1.73781D-03
#
# At iterate   20    f=  3.24484D+00    |proj g|=  4.59097D-03
#
# At iterate   25    f=  3.24424D+00    |proj g|=  4.41513D-03
#
# ...
#
# At iterate    5    f=  3.44700D+00    |proj g|=  5.58991D-02
#
# At iterate   10    f=  3.33826D+00    |proj g|=  1.25000D-01
#
# At iterate   15    f=  3.25689D+00    |proj g|=  4.37691D-02
#
# At iterate   20    f=  3.25086D+00    |proj g|=  5.48203D-04
#
# At iterate   25    f=  3.25084D+00    |proj g|=  6.11408D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     26     35      1     0     0   4.488D-06   3.251D+00
#   F =   3.2508439617968543
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27385D+00    |proj g|=  1.53181D-01
#
# At iterate    5    f=  3.25716D+00    |proj g|=  1.05770D-02
#
# At iterate   10    f=  3.25358D+00    |proj g|=  4.64902D-03
#
# At iterate   15    f=  3.25354D+00    |proj g|=  1.81139D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     16     19      1     0     0   1.327D-05   3.254D+00
#   F =   3.2535400306311444
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27488D+00    |proj g|=  1.52763D-01
#
# At iterate    5    f=  3.25872D+00    |proj g|=  1.53890D-02
#
# At iterate   10    f=  3.25316D+00    |proj g|=  6.93419D-03
#
# At iterate   15    f=  3.25306D+00    |proj g|=  2.04794D-03
#
# At iterate   20    f=  3.25297D+00    |proj g|=  2.90241D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     20     24      1     0     0   2.902D-05   3.253D+00
#   F =   3.2529685384174640
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.44370D+00    |proj g|=  1.57518D-01
#
# At iterate    5    f=  3.30810D+00    |proj g|=  7.39777D-02
#
# At iterate   10    f=  3.25951D+00    |proj g|=  1.68621D-02
#
# At iterate   15    f=  3.22320D+00    |proj g|=  2.36009D-02
#
# At iterate   20    f=  3.22074D+00    |proj g|=  2.57930D-03
#
# At iterate   25    f=  3.21983D+00    |proj g|=  5.79105D-04
#
# At iterate   30    f=  3.21983D+00    |proj g|=  2.34479D-04
#
# At iterate   35    f=  3.21980D+00    |proj g|=  1.32771D-03
#
# At iterate   40    f=  3.21973D+00    |proj g|=  3.83044D-04
#
# At iterate   45    f=  3.21972D+00    |proj g|=  3.77586D-04
#
# At iterate   50    f=  3.21971D+00    |proj g|=  9.59443D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     64      1     0     0   9.594D-04   3.220D+00
#   F =   3.2197062065016913
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27347D+00    |proj g|=  1.44934D-01
#
# At iterate    5    f=  3.25596D+00    |proj g|=  6.54637D-03
#
# At iterate   10    f=  3.25226D+00    |proj g|=  1.46434D-02
#
# At iterate   15    f=  3.25208D+00    |proj g|=  4.43357D-04
#
# At iterate   20    f=  3.25207D+00    |proj g|=  1.62835D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     21     23      1     0     0   6.533D-06   3.252D+00
#   F =   3.2520699190088909
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27520D+00    |proj g|=  1.48620D-01
#
# At iterate    5    f=  3.25408D+00    |proj g|=  8.23570D-03
#
# At iterate   10    f=  3.23585D+00    |proj g|=  9.08871D-03
#
# At iterate   15    f=  3.23277D+00    |proj g|=  2.51852D-03
#
# At iterate   20    f=  3.23131D+00    |proj g|=  2.55641D-03
#
# At iterate   25    f=  3.22728D+00    |proj g|=  8.87523D-03
#
# At iterate   30    f=  3.22697D+00    |proj g|=  1.19761D-03
#
# At iterate   35    f=  3.22695D+00    |proj g|=  2.31849D-03
#
# At iterate   40    f=  3.22685D+00    |proj g|=  3.59172D-03
#
# At iterate   45    f=  3.22681D+00    |proj g|=  3.17337D-04
#
# At iterate   50    f=  3.22681D+00    |proj g|=  9.46635D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     62      1     0     0   9.466D-05   3.227D+00
#   F =   3.2268107759343505
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
# /usr/local/lib/python3.8/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# SARIMA: (2, 1, 1)(2, 1, 2, 12) >> AIC : 70.47
# SARIMA: (2, 1, 2)(0, 1, 0, 12) >> AIC : 755.2
# SARIMA: (2, 1, 2)(0, 1, 1, 12) >> AIC : 755.99
# SARIMA: (2, 1, 2)(0, 1, 2, 12) >> AIC : 759.77
# SARIMA: (2, 1, 2)(1, 1, 0, 12) >> AIC : 755.82
# SARIMA: (2, 1, 2)(1, 1, 1, 12) >> AIC : 757.71
# /usr/local/lib/python3.8/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# SARIMA: (2, 1, 2)(1, 1, 2, 12) >> AIC : 752.34
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.44448D+00    |proj g|=  3.83504D-01
#
# At iterate    5    f=  3.27164D+00    |proj g|=  1.91820D-02
#
# At iterate   10    f=  3.25608D+00    |proj g|=  1.16135D-02
#
# At iterate   15    f=  3.25557D+00    |proj g|=  1.59466D-03
#
# At iterate   20    f=  2.71628D-01    |proj g|=  3.38951D+03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     23    104      2     0     0   2.516D+04   2.368D-01
#   F =  0.23682336300993140
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.26180D+00    |proj g|=  3.91551D-02
#
# At iterate    5    f=  3.25347D+00    |proj g|=  1.30436D-02
#
# At iterate   10    f=  3.24468D+00    |proj g|=  1.97256D-02
#
# At iterate   15    f=  3.24084D+00    |proj g|=  1.15478D-02
#
# At iterate   20    f=  3.24008D+00    |proj g|=  1.64394D-03
#
# At iterate   25    f=  3.24000D+00    |proj g|=  7.18862D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     26     29      1     0     0   6.972D-06   3.240D+00
#   F =   3.2400030866811615
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.25671D+00    |proj g|=  4.34123D-02
#
# At iterate    5    f=  3.25042D+00    |proj g|=  5.70547D-02
#
# At iterate   10    f=  3.24273D+00    |proj g|=  1.48299D-02
#
# At iterate   15    f=  3.23498D+00    |proj g|=  6.62053D-03
#
# At iterate   20    f=  3.23476D+00    |proj g|=  5.42692D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     24     27      1     0     0   4.553D-06   3.235D+00
#   F =   3.2347276386636814
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.51612D+00    |proj g|=  2.10919D-01
#
# At iterate    5    f=  3.46374D+00    |proj g|=  3.98386D-02
#
# At iterate   10    f=  3.30765D+00    |proj g|=  6.02977D-02
#
# At iterate   15    f=  3.25118D+00    |proj g|=  1.26731D-02
#
# At iterate   20    f=  3.25049D+00    |proj g|=  2.13180D-02
#
# At iterate   25    f=  3.24899D+00    |proj g|=  2.85184D-03
#
# At iterate   30    f=  3.24763D+00    |proj g|=  3.39442D-02
#
# At iterate   35    f=  3.24276D+00    |proj g|=  1.65116D-02
#
# At iterate   40    f=  3.24248D+00    |proj g|=  1.86725D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     41     54      1     0     0   1.637D-06   3.242D+00
#   F =   3.2424792974024679
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.25677D+00    |proj g|=  4.25641D-02
#
# At iterate    5    f=  3.25005D+00    |proj g|=  6.52235D-02
#
# At iterate   10    f=  3.24088D+00    |proj g|=  1.76952D-02
#
# At iterate   15    f=  3.23471D+00    |proj g|=  6.45395D-03
#
# At iterate   20    f=  3.23401D+00    |proj g|=  3.65723D-04
#
# At iterate   25    f=  3.23400D+00    |proj g|=  3.28894D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     27     30      1     0     0   5.899D-06   3.234D+00
#   F =   3.2340030686667354
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.25772D+00    |proj g|=  4.46051D-02
#
# At iterate    5    f=  3.24724D+00    |proj g|=  4.11210D-02
#
# At iterate   10    f=  3.24016D+00    |proj g|=  1.21821D-02
#
# At iterate   15    f=  3.23399D+00    |proj g|=  8.01978D-03
#
# At iterate   20    f=  3.23355D+00    |proj g|=  1.06797D-03
#
# At iterate   25    f=  3.23354D+00    |proj g|=  1.80661D-04
#
# At iterate   30    f=  3.23354D+00    |proj g|=  7.68106D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     30     34      1     0     0   7.681D-06   3.234D+00
#   F =   3.2335403372619629
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.46605D+00    |proj g|=  2.33185D-01
#
# At iterate    5    f=  3.28323D+00    |proj g|=  3.61686D-02
#
# At iterate   10    f=  3.22364D+00    |proj g|=  1.35273D-02
#
# At iterate   15    f=  3.21060D+00    |proj g|=  2.44736D-02
#
# At iterate   20    f=  3.20543D+00    |proj g|=  4.99848D-03
#
# At iterate   25    f=  3.20164D+00    |proj g|=  5.37273D-03
#
# At iterate   30    f=  3.20147D+00    |proj g|=  1.41164D-04
#
# At iterate   35    f=  3.20147D+00    |proj g|=  1.97794D-05
#
# At iterate   40    f=  3.20147D+00    |proj g|=  7.73794D-04
#
# At iterate   45    f=  3.20147D+00    |proj g|=  2.41010D-04
#
# At iterate   50    f=  3.20147D+00    |proj g|=  2.88240D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     64      1     0     0   2.882D-04   3.201D+00
#   F =   3.2014659903085914
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# SARIMA: (2, 1, 2)(2, 1, 0, 12) >> AIC : 757.56
# SARIMA: (2, 1, 2)(2, 1, 1, 12) >> AIC : 753.96

# %%
# Search optimal parameters
SARIMA_optimal = [(params[i], j) for i, j in enumerate(aic) if j == min(aic)]
SARIMA_optimal
# Out:
# [(((2, 1, 1), (2, 1, 2, 12)), 70.47)]

# %%
SARIMA_model_opt = SARIMAX(train.values, order=SARIMA_optimal[0][0][0], seasonal_order = SARIMA_optimal[0][0][1])
SARIMA_model_opt_fit = SARIMA_model_opt.fit()

SARIMA_model_opt_fit.summary()
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                  115
# Model:             SARIMAX(2, 1, 1)x(2, 1, [1, 2], 12)   Log Likelihood                 -27.235
# Date:                                 Wed, 08 Feb 2023   AIC                             70.469
# Time:                                         17:06:04   BIC                             91.469
# Sample:                                              0   HQIC                            78.973
#                                                  - 115
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2101   3.27e-08   6.42e+06      0.000       0.210       0.210
# ar.L2          0.1821   7.57e-10   2.41e+08      0.000       0.182       0.182
# ma.L1         -0.3876   1.61e-08  -2.41e+07      0.000      -0.388      -0.388
# ar.S.L12       0.0009   1.17e-07   7808.009      0.000       0.001       0.001
# ar.S.L24       0.9991   1.46e-08   6.82e+07      0.000       0.999       0.999
# ma.S.L12      -0.0009   2.51e-08  -3.77e+04      0.000      -0.001      -0.001
# ma.S.L24      -0.9962      7e-10  -1.42e+09      0.000      -0.996      -0.996
# sigma2        67.9771   2.22e-11   3.06e+12      0.000      67.977      67.977
# ===================================================================================
# Ljung-Box (L1) (Q):                  40.02   Jarque-Bera (JB):              3760.42
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.00   Skew:                             5.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                        30.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.51e+23. Standard errors may be unstable.
# """

# %% [markdown]
# #### 3.5.2 use Model to Forecast - SARIMA

# %%
SARIMA_prediction = SARIMA_model_opt_fit.get_forecast(len(test))
SARIMA_test_pred = SARIMA_prediction.predicted_mean
SARIMA_test_ub = SARIMA_prediction.conf_int()[:,0]
SARIMA_test_lb = SARIMA_prediction.conf_int()[:,1]
predict_index = list(test.index)

# %%
'''
Quantitative Evaluation
'''
print('SARIMA')
print('-'*30)
print(f'MSE: {np.round(mean_squared_error(test, SARIMA_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,SARIMA_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, SARIMA_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, SARIMA_test_pred), 2)}')
# Out:
# SARIMA
# ------------------------------
# MSE: 33104915.1
# RMSE: 5753.69
# MAE: 5696.54
# R2 score: -5422.04

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(data.index, data.values, label = 'Passengers')
ax.vlines(datetime.datetime.strptime('1958-08-01','%Y-%m-%d'), 0, 700, linestyle='--', color='r', label='Start of Forecast')
ax.plot(predict_index, SARIMA_test_pred, label = 'Prediction')
ax.fill_between(predict_index, SARIMA_test_lb, SARIMA_test_ub, color = 'k', alpha = 0.1, label='0.95 Prediction Interval')
ax.legend(loc='upper left')
plt.suptitle(f'SARIMA {SARIMA_optimal[0][0][0]},{SARIMA_optimal[0][0][1]} Prediction Results (r2_score: {np.round(r2_score(test, SARIMA_test_pred), 2)})')
plt.show()

# %% [markdown]
# #### 3.4.3 Diagnosis Check - auto_arima

# %%
# Parameter search 

auto_arima_model = auto_arima(train, start_p=1, start_q=1,
                              max_p=3, max_q=3, m=12, seasonal=True,
                              d=1, D=1, 
                              max_P=3, max_Q=3,
                              trace=True,
                              error_action='ignore',  
                              suppress_warnings=True, 
                              stepwise=False)
# Out:
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=757.826, Time=0.01 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=756.988, Time=0.04 sec
#  ARIMA(0,1,0)(0,1,2)[12]             : AIC=758.826, Time=0.39 sec
#  ARIMA(0,1,0)(0,1,3)[12]             : AIC=758.186, Time=0.79 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=756.959, Time=0.05 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=758.922, Time=0.12 sec
#  ARIMA(0,1,0)(1,1,2)[12]             : AIC=inf, Time=1.09 sec
#  ARIMA(0,1,0)(1,1,3)[12]             : AIC=754.685, Time=1.97 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=758.869, Time=0.12 sec
#  ARIMA(0,1,0)(2,1,1)[12]             : AIC=760.726, Time=0.54 sec
#  ARIMA(0,1,0)(2,1,2)[12]             : AIC=inf, Time=1.63 sec
#  ARIMA(0,1,0)(2,1,3)[12]             : AIC=756.686, Time=2.87 sec
#  ARIMA(0,1,0)(3,1,0)[12]             : AIC=759.643, Time=0.44 sec
#  ARIMA(0,1,0)(3,1,1)[12]             : AIC=inf, Time=2.47 sec
#  ARIMA(0,1,0)(3,1,2)[12]             : AIC=756.688, Time=2.71 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=756.011, Time=0.02 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=756.380, Time=0.07 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=757.653, Time=0.52 sec
#  ARIMA(0,1,1)(0,1,3)[12]             : AIC=756.866, Time=0.72 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=756.166, Time=0.05 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=758.107, Time=0.15 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=inf, Time=2.46 sec
#  ARIMA(0,1,1)(1,1,3)[12]             : AIC=752.982, Time=2.02 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=757.994, Time=0.15 sec
#  ARIMA(0,1,1)(2,1,1)[12]             : AIC=inf, Time=1.13 sec
#  ARIMA(0,1,1)(2,1,2)[12]             : AIC=inf, Time=nan sec
#  ARIMA(0,1,1)(3,1,0)[12]             : AIC=758.104, Time=0.42 sec
#  ARIMA(0,1,1)(3,1,1)[12]             : AIC=inf, Time=2.76 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=757.778, Time=0.03 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=758.043, Time=0.12 sec
#  ARIMA(0,1,2)(0,1,2)[12]             : AIC=759.284, Time=0.63 sec
#  ARIMA(0,1,2)(0,1,3)[12]             : AIC=758.652, Time=0.82 sec
#  ARIMA(0,1,2)(1,1,0)[12]             : AIC=757.811, Time=0.07 sec
#  ARIMA(0,1,2)(1,1,1)[12]             : AIC=759.751, Time=0.14 sec
#  ARIMA(0,1,2)(1,1,2)[12]             : AIC=inf, Time=1.91 sec
#  ARIMA(0,1,2)(2,1,0)[12]             : AIC=759.641, Time=0.51 sec
#  ARIMA(0,1,2)(2,1,1)[12]             : AIC=inf, Time=1.29 sec
#  ARIMA(0,1,2)(3,1,0)[12]             : AIC=759.804, Time=0.62 sec
#  ARIMA(0,1,3)(0,1,0)[12]             : AIC=752.936, Time=0.05 sec
#  ARIMA(0,1,3)(0,1,1)[12]             : AIC=753.809, Time=0.14 sec
#  ARIMA(0,1,3)(0,1,2)[12]             : AIC=755.269, Time=0.88 sec
#  ARIMA(0,1,3)(1,1,0)[12]             : AIC=753.663, Time=0.11 sec
#  ARIMA(0,1,3)(1,1,1)[12]             : AIC=755.497, Time=0.29 sec
#  ARIMA(0,1,3)(2,1,0)[12]             : AIC=755.384, Time=0.27 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=755.499, Time=0.02 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=755.982, Time=0.07 sec
#  ARIMA(1,1,0)(0,1,2)[12]             : AIC=757.103, Time=0.47 sec
#  ARIMA(1,1,0)(0,1,3)[12]             : AIC=756.433, Time=0.60 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=755.750, Time=0.05 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=757.649, Time=0.08 sec
#  ARIMA(1,1,0)(1,1,2)[12]             : AIC=inf, Time=1.61 sec
#  ARIMA(1,1,0)(1,1,3)[12]             : AIC=752.557, Time=1.64 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=757.453, Time=0.19 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=1.64 sec
#  ARIMA(1,1,0)(2,1,2)[12]             : AIC=inf, Time=nan sec
#  ARIMA(1,1,0)(3,1,0)[12]             : AIC=757.510, Time=0.49 sec
#  ARIMA(1,1,0)(3,1,1)[12]             : AIC=inf, Time=2.91 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=756.022, Time=0.02 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=756.629, Time=0.08 sec
#  ARIMA(1,1,1)(0,1,2)[12]             : AIC=757.749, Time=0.56 sec
#  ARIMA(1,1,1)(0,1,3)[12]             : AIC=757.733, Time=1.21 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=756.406, Time=0.09 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=758.260, Time=0.16 sec
#  ARIMA(1,1,1)(1,1,2)[12]             : AIC=inf, Time=1.94 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=758.031, Time=0.63 sec
#  ARIMA(1,1,1)(2,1,1)[12]             : AIC=inf, Time=2.45 sec
#  ARIMA(1,1,1)(3,1,0)[12]             : AIC=758.462, Time=0.89 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=757.925, Time=0.04 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=758.441, Time=0.20 sec
#  ARIMA(1,1,2)(0,1,2)[12]             : AIC=759.634, Time=0.97 sec
#  ARIMA(1,1,2)(1,1,0)[12]             : AIC=758.220, Time=0.13 sec
#  ARIMA(1,1,2)(1,1,1)[12]             : AIC=760.100, Time=0.33 sec
#  ARIMA(1,1,2)(2,1,0)[12]             : AIC=759.915, Time=0.35 sec
#  ARIMA(1,1,3)(0,1,0)[12]             : AIC=754.178, Time=0.08 sec
#  ARIMA(1,1,3)(0,1,1)[12]             : AIC=753.995, Time=0.24 sec
#  ARIMA(1,1,3)(1,1,0)[12]             : AIC=753.975, Time=0.20 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=756.771, Time=0.02 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : AIC=757.226, Time=0.06 sec
#  ARIMA(2,1,0)(0,1,2)[12]             : AIC=758.313, Time=0.71 sec
#  ARIMA(2,1,0)(0,1,3)[12]             : AIC=758.011, Time=0.67 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=756.982, Time=0.07 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=758.859, Time=0.13 sec
#  ARIMA(2,1,0)(1,1,2)[12]             : AIC=inf, Time=1.87 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=758.650, Time=0.27 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=1.13 sec
#  ARIMA(2,1,0)(3,1,0)[12]             : AIC=758.903, Time=0.50 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=757.976, Time=0.04 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=758.537, Time=0.14 sec
#  ARIMA(2,1,1)(0,1,2)[12]             : AIC=759.694, Time=0.65 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=758.314, Time=0.12 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=760.183, Time=0.25 sec
#  ARIMA(2,1,1)(2,1,0)[12]             : AIC=759.976, Time=0.37 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=755.201, Time=0.08 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=755.987, Time=0.20 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=755.821, Time=0.20 sec
#  ARIMA(2,1,3)(0,1,0)[12]             : AIC=755.253, Time=0.12 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=755.605, Time=0.02 sec
#  ARIMA(3,1,0)(0,1,1)[12]             : AIC=756.424, Time=0.07 sec
#  ARIMA(3,1,0)(0,1,2)[12]             : AIC=757.829, Time=0.79 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=756.268, Time=0.09 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=758.159, Time=0.14 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=758.003, Time=0.22 sec
#  ARIMA(3,1,1)(0,1,0)[12]             : AIC=754.435, Time=0.06 sec
#  ARIMA(3,1,1)(0,1,1)[12]             : AIC=754.694, Time=0.18 sec
#  ARIMA(3,1,1)(1,1,0)[12]             : AIC=754.571, Time=0.18 sec
#  ARIMA(3,1,2)(0,1,0)[12]             : AIC=inf, Time=0.14 sec
#
# Best model:  ARIMA(1,1,0)(1,1,3)[12]
# Total fit time: 67.788 seconds

# %%
auto_arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ==================================================================================================
# Dep. Variable:                                          y   No. Observations:                  115
# Model:             SARIMAX(1, 1, 0)x(1, 1, [1, 2, 3], 12)   Log Likelihood                -370.278
# Date:                                    Wed, 08 Feb 2023   AIC                            752.557
# Time:                                            17:07:22   BIC                            768.307
# Sample:                                        01-01-1949   HQIC                           758.934
#                                              - 07-01-1958
# Covariance Type:                                      opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2218      0.093     -2.388      0.017      -0.404      -0.040
# ar.S.L12       0.9288      0.275      3.374      0.001       0.389       1.468
# ma.S.L12      -1.2065      0.448     -2.692      0.007      -2.085      -0.328
# ma.S.L24       0.2771      0.174      1.596      0.111      -0.063       0.618
# ma.S.L36       0.1251      0.164      0.765      0.444      -0.195       0.446
# sigma2        75.0386     19.073      3.934      0.000      37.656     112.421
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 2.50
# Prob(Q):                              0.91   Prob(JB):                         0.29
# Heteroskedasticity (H):               1.05   Skew:                             0.37
# Prob(H) (two-sided):                  0.90   Kurtosis:                         2.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# #### 3.5.3 use Model to Forecast - auto_arima

# %%
AUTO_ARIMA_prediction = auto_arima_model.predict(len(test), return_conf_int=True)
AUTO_ARIMA_test_pred = AUTO_ARIMA_prediction[0]
AUTO_ARIMA_test_ub = AUTO_ARIMA_prediction[1][:,0]
AUTO_ARIMA_test_lb = AUTO_ARIMA_prediction[1][:,1]
predict_index = list(test.index)

# %%
'''
Quantitative Evaluation
'''
print('AUTO ARIMA')
print('-'*30)
print(f'MSE: {np.round(mean_squared_error(test, AUTO_ARIMA_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,AUTO_ARIMA_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, AUTO_ARIMA_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, AUTO_ARIMA_test_pred), 2)}')
# Out:
# AUTO ARIMA
# ------------------------------
# MSE: 710.43
# RMSE: 26.65
# MAE: 22.16
# R2 score: 0.88

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(data.index, data.values, label = 'Passengers')
ax.vlines(datetime.datetime.strptime('1958-08-01','%Y-%m-%d'), 0, 700, linestyle='--', color='r', label='Start of Forecast')
ax.plot(predict_index, AUTO_ARIMA_test_pred, label = 'Prediction')
ax.fill_between(predict_index, AUTO_ARIMA_test_lb, AUTO_ARIMA_test_ub, color = 'k', alpha = 0.1, label='0.95 Prediction Interval')
ax.legend(loc='upper left')
plt.suptitle(f'SARIMA {auto_arima_model.order},{auto_arima_model.seasonal_order} Prediction Results (r2_score: {np.round(r2_score(test, AUTO_ARIMA_test_pred), 2)})')
plt.show()

# %% [markdown]
# ### 4. Prophet

# %%
train_prophet = train.reset_index()
train_prophet
# Out:
#          month  passengers
# 0   1949-01-01         112
# 1   1949-02-01         118
# 2   1949-03-01         132
# 3   1949-04-01         129
# 4   1949-05-01         121
# ..         ...         ...
# 110 1958-03-01         362
# 111 1958-04-01         348
# 112 1958-05-01         363
# 113 1958-06-01         435
# 114 1958-07-01         491
#
# [115 rows x 2 columns]

# %%
train_prophet.columns = ['ds', 'y']
train_prophet
# Out:
#             ds    y
# 0   1949-01-01  112
# 1   1949-02-01  118
# 2   1949-03-01  132
# 3   1949-04-01  129
# 4   1949-05-01  121
# ..         ...  ...
# 110 1958-03-01  362
# 111 1958-04-01  348
# 112 1958-05-01  363
# 113 1958-06-01  435
# 114 1958-07-01  491
#
# [115 rows x 2 columns]

# %%
PRO_model = Prophet()
PRO_model.fit(train_prophet)
# Out:
# 17:07:23 - cmdstanpy - INFO - Chain [1] start processing
# 17:07:23 - cmdstanpy - INFO - Chain [1] done processing

# %%
test_prophet = test.reset_index()
test_prophet.columns = ['ds', 'y']
test_data_index = test_prophet[['ds']]
test_data_index
# Out:
#            ds
# 0  1958-08-01
# 1  1958-09-01
# 2  1958-10-01
# 3  1958-11-01
# 4  1958-12-01
# 5  1959-01-01
# 6  1959-02-01
# 7  1959-03-01
# 8  1959-04-01
# 9  1959-05-01
# 10 1959-06-01
# 11 1959-07-01
# 12 1959-08-01
# 13 1959-09-01
# 14 1959-10-01
# 15 1959-11-01
# 16 1959-12-01
# 17 1960-01-01
# 18 1960-02-01
# 19 1960-03-01
# 20 1960-04-01
# 21 1960-05-01
# 22 1960-06-01
# 23 1960-07-01
# 24 1960-08-01
# 25 1960-09-01
# 26 1960-10-01
# 27 1960-11-01
# 28 1960-12-01

# %%
PRO_prediction = PRO_model.predict(test_data_index)
PRO_prediction
# Out:
#            ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0  1958-08-01  401.246072  427.433346  470.402217   401.244427   401.246917
# 1  1958-09-01  404.406036  397.561084  442.816696   404.381853   404.426402
# 2  1958-10-01  407.464066  365.417150  408.680999   407.405891   407.515393
# 3  1958-11-01  410.624030  338.904875  382.473428   410.504398   410.713696
# 4  1958-12-01  413.682060  367.083422  410.328734   413.503295   413.825843
# 5  1959-01-01  416.842024  374.021246  417.389868   416.589686   417.049333
# 6  1959-02-01  420.001988  372.940822  414.660762   419.672717   420.273269
# 7  1959-03-01  422.856149  402.823912  446.255617   422.432196   423.196994
# 8  1959-04-01  426.016113  397.902246  441.167954   425.512467   426.456922
# 9  1959-05-01  429.074143  403.519313  447.272310   428.475319   429.592793
# 10 1959-06-01  432.234107  436.827022  479.573065   431.529180   432.841179
# 11 1959-07-01  435.292137  472.163270  517.065293   434.492477   435.998550
# 12 1959-08-01  438.452101  460.413888  504.437839   437.536133   439.267853
# 13 1959-09-01  441.612065  433.459353  478.415484   440.579429   442.525050
# 14 1959-10-01  444.670095  403.541151  446.722297   443.536360   445.681163
# 15 1959-11-01  447.830059  377.495313  421.694519   446.565668   448.963273
# 16 1959-12-01  450.888088  406.034170  449.070120   449.486576   452.135533
# 17 1960-01-01  454.048052  410.818060  452.614839   452.532659   455.436200
# 18 1960-02-01  457.208017  410.063606  453.424891   455.536546   458.725281
# 19 1960-03-01  460.164112  443.789052  488.235957   458.364410   461.792734
# 20 1960-04-01  463.324076  435.749046  479.980069   461.359879   465.073174
# 21 1960-05-01  466.382106  436.583419  482.757758   464.302085   468.234186
# 22 1960-06-01  469.542070  477.676606  520.137004   467.300165   471.531721
# 23 1960-07-01  472.600100  503.044756  548.135032   470.231119   474.688122
# 24 1960-08-01  475.760064  507.466034  550.141048   473.312901   477.981395
# 25 1960-09-01  478.920028  470.222858  515.396970   476.334350   481.243030
# 26 1960-10-01  481.978058  439.270309  484.132380   479.245174   484.484202
# 27 1960-11-01  485.138022  414.174264  457.157194   482.255694   487.809761
# 28 1960-12-01  488.196051  441.412492  485.642590   485.190142   491.080728
#
#     additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0        47.296163             47.296163             47.296163  47.296163
# 1        14.332728             14.332728             14.332728  14.332728
# 2       -19.364225            -19.364225            -19.364225 -19.364225
# 3       -48.707184            -48.707184            -48.707184 -48.707184
# 4       -24.872170            -24.872170            -24.872170 -24.872170
# 5       -21.153576            -21.153576            -21.153576 -21.153576
# 6       -26.142668            -26.142668            -26.142668 -26.142668
# 7         2.047491              2.047491              2.047491   2.047491
# 8        -6.321966             -6.321966             -6.321966  -6.321966
# 9        -3.747460             -3.747460             -3.747460  -3.747460
# 10       26.667997             26.667997             26.667997  26.667997
# 11       59.625395             59.625395             59.625395  59.625395
# 12       44.574307             44.574307             44.574307  44.574307
# 13       14.768787             14.768787             14.768787  14.768787
# 14      -18.763278            -18.763278            -18.763278 -18.763278
# 15      -48.268752            -48.268752            -48.268752 -48.268752
# 16      -24.242908            -24.242908            -24.242908 -24.242908
# 17      -22.175168            -22.175168            -22.175168 -22.175168
# 18      -25.343514            -25.343514            -25.343514 -25.343514
# 19        5.895525              5.895525              5.895525   5.895525
# 20       -4.689297             -4.689297             -4.689297  -4.689297
# 21       -7.874228             -7.874228             -7.874228  -7.874228
# 22       29.097130             29.097130             29.097130  29.097130
# 23       53.711930             53.711930             53.711930  53.711930
# 24       52.654024             52.654024             52.654024  52.654024
# 25       13.575913             13.575913             13.575913  13.575913
# 26      -20.513189            -20.513189            -20.513189 -20.513189
# 27      -49.540401            -49.540401            -49.540401 -49.540401
# 28      -26.202310            -26.202310            -26.202310 -26.202310
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 0      47.296163     47.296163                   0.0
# 1      14.332728     14.332728                   0.0
# 2     -19.364225    -19.364225                   0.0
# 3     -48.707184    -48.707184                   0.0
# 4     -24.872170    -24.872170                   0.0
# 5     -21.153576    -21.153576                   0.0
# 6     -26.142668    -26.142668                   0.0
# 7       2.047491      2.047491                   0.0
# 8      -6.321966     -6.321966                   0.0
# 9      -3.747460     -3.747460                   0.0
# 10     26.667997     26.667997                   0.0
# 11     59.625395     59.625395                   0.0
# 12     44.574307     44.574307                   0.0
# 13     14.768787     14.768787                   0.0
# 14    -18.763278    -18.763278                   0.0
# 15    -48.268752    -48.268752                   0.0
# 16    -24.242908    -24.242908                   0.0
# 17    -22.175168    -22.175168                   0.0
# 18    -25.343514    -25.343514                   0.0
# 19      5.895525      5.895525                   0.0
# 20     -4.689297     -4.689297                   0.0
# 21     -7.874228     -7.874228                   0.0
# 22     29.097130     29.097130                   0.0
# 23     53.711930     53.711930                   0.0
# 24     52.654024     52.654024                   0.0
# 25     13.575913     13.575913                   0.0
# 26    -20.513189    -20.513189                   0.0
# 27    -49.540401    -49.540401                   0.0
# 28    -26.202310    -26.202310                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                          0.0                         0.0  448.542235
# 1                          0.0                         0.0  418.738764
# 2                          0.0                         0.0  388.099841
# 3                          0.0                         0.0  361.916846
# 4                          0.0                         0.0  388.809889
# 5                          0.0                         0.0  395.688448
# 6                          0.0                         0.0  393.859320
# 7                          0.0                         0.0  424.903640
# 8                          0.0                         0.0  419.694147
# 9                          0.0                         0.0  425.326683
# 10                         0.0                         0.0  458.902104
# 11                         0.0                         0.0  494.917531
# 12                         0.0                         0.0  483.026408
# 13                         0.0                         0.0  456.380852
# 14                         0.0                         0.0  425.906816
# 15                         0.0                         0.0  399.561307
# 16                         0.0                         0.0  426.645180
# 17                         0.0                         0.0  431.872884
# 18                         0.0                         0.0  431.864502
# 19                         0.0                         0.0  466.059637
# 20                         0.0                         0.0  458.634779
# 21                         0.0                         0.0  458.507877
# 22                         0.0                         0.0  498.639200
# 23                         0.0                         0.0  526.312029
# 24                         0.0                         0.0  528.414088
# 25                         0.0                         0.0  492.495941
# 26                         0.0                         0.0  461.464869
# 27                         0.0                         0.0  435.597621
# 28                         0.0                         0.0  461.993742

# %%
PRO_test_pred = PRO_prediction['yhat'].values
PRO_test_ub = PRO_prediction['yhat_upper'].values
PRO_test_lb = PRO_prediction['yhat_lower'].values
predict_index = list(test.index)

# %%
'''
Quantitative Evaluation
'''
print('Prophet')
print('-'*30)
print(f'MSE: {np.round(mean_squared_error(test, PRO_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,PRO_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, PRO_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, PRO_test_pred), 2)}')
# Out:
# Prophet
# ------------------------------
# MSE: 1710.13
# RMSE: 41.35
# MAE: 34.01
# R2 score: 0.72

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(data.index, data.values, label = 'Passengers')
ax.vlines(datetime.datetime.strptime('1958-08-01','%Y-%m-%d'), 0, 700, linestyle='--', color='r', label='Start of Forecast')
ax.plot(predict_index, PRO_test_pred, label = 'Prediction')
ax.fill_between(predict_index, PRO_test_lb, PRO_test_ub, color = 'k', alpha = 0.1, label='0.95 Prediction Interval')
ax.legend(loc='upper left')
plt.title(f'Prophet Prediction Results (r2_score: {np.round(r2_score(test, PRO_test_pred), 2)})')
plt.show()

# %%
'''
Moving Average
'''
MA_train_pred = train.rolling(5).mean() # Option: min_periods=1
MA_train_pred.columns = ['MA_5']
MA_test_pred = pd.DataFrame(np.array([MA_train_pred.iloc[-1]]*len(test)), index=test.index, columns=['MA_5'])

'''
Simple Eponential Smoothing
'''
L_0 = np.mean(train)  # initial value

SES_train = train.copy()
SES_train = pd.concat([pd.DataFrame(np.zeros(1), columns=['passengers']), SES_train])
SES_train['Level'] = np.nan
SES_train['Forecast'] = np.nan
SES_train.loc[0,'Level'] = L_0.values

SES_train_pred_09 = pd.concat([pd.DataFrame([L_0], columns=['passengers']), train]).ewm(alpha=0.9, adjust=False).mean().iloc[1:]
SES_train_pred_09.columns = ['SES_09']
SES_test_pred_09 = pd.DataFrame(np.array([SES_train_pred_09.iloc[-1]]*len(test)),
                                index=test.index, columns=['SES_09'])

'''
Double Eponential Smoothing
'''
train_reg = train.reset_index()
x = np.array(train_reg.index)
y = train_reg['passengers']

x = sm.add_constant(x)
model = sm.OLS(y,x)
results = model.fit()

print(results.summary())
L_0, B_0 = results.params

DES_train = train.copy()
DES_train = pd.concat([pd.DataFrame(np.zeros(1), columns=['passengers']), DES_train])
DES_train['Level'] = np.nan
DES_train['Trend'] = np.nan
DES_train['Forecast'] = np.nan

DES_train.loc[0,'Level'] = L_0
DES_train.loc[0,'Trend'] = B_0

def Double_Exponential_Smoothing(table, alpha, beta):
    # table = DES_train.copy()
    # alpha = 0.16
    # beta = 0.1
    for i in range(len(table)):
        if i == 0: # Skip initialization point
            continue

        x = table.loc[list(table.index)[i],'passengers']
        L_prev = table.loc[list(table.index)[i-1],'Level']
        T_prev = table.loc[list(table.index)[i-1],'Trend']
        
        table.loc[list(table.index)[i],'Level'] = alpha*x + (1-alpha)*(L_prev+T_prev)
        table.loc[list(table.index)[i],'Trend'] = beta*(table.loc[list(table.index)[i],'Level']-L_prev) + (1-beta)*(T_prev)

        L_Pred = table.iloc[-1,1]
        T_Pred = table.iloc[-1,2]
        
        DES_test_pred = L_Pred + range(len(test))*T_Pred
        DES_test_pred = pd.DataFrame(DES_test_pred, index = test.index, columns=['DES'])
        
    return table, DES_test_pred

DES_train_pred, DES_test_pred = Double_Exponential_Smoothing(DES_train, 0.1, 0.1)

'''
Additive Holt-winter
'''

HW_add_model = ExponentialSmoothing(train, trend='add', seasonal='add').fit(optimized=True)
HW_add_train_pred = HW_add_model.fittedvalues
HW_add_test_pred = HW_add_model.forecast(len(test))
HW_add_test_pred = pd.DataFrame(HW_add_test_pred, index=test.index, columns=['HW_add'])


'''
Multiplicative Holt-winter
'''
HW_mul_model = ExponentialSmoothing(train, trend='mul', seasonal='mul').fit(optimized=True)
HW_mul_train_pred = HW_mul_model.fittedvalues
HW_mul_test_pred = HW_mul_model.forecast(len(test))
HW_mul_test_pred = pd.DataFrame(HW_mul_test_pred, index=test.index, columns=['HW_mul'])
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             passengers   R-squared:                       0.842
# Model:                            OLS   Adj. R-squared:                  0.840
# Method:                 Least Squares   F-statistic:                     600.9
# Date:                Wed, 08 Feb 2023   Prob (F-statistic):           4.79e-47
# Time:                        17:07:26   Log-Likelihood:                -575.87
# No. Observations:                 115   AIC:                             1156.
# Df Residuals:                     113   BIC:                             1161.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         96.6742      6.764     14.293      0.000      83.274     110.075
# x1             2.5136      0.103     24.513      0.000       2.310       2.717
# ==============================================================================
# Omnibus:                       14.985   Durbin-Watson:                   0.541
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.110
# Skew:                           0.791   Prob(JB):                     0.000193
# Kurtosis:                       4.032   Cond. No.                         131.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
'''
Quantitative Evaluation
'''
print('-'*55)
print('Moving Average (N = 5)')
print(f'MSE: {np.round(mean_squared_error(test, MA_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,MA_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, MA_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, MA_test_pred), 2)}')

print('-'*55)
print('Simple Exponential Smoothing (alpha = 0.9)')
print(f'MSE: {np.round(mean_squared_error(test, SES_test_pred_09), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,SES_test_pred_09)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, SES_test_pred_09), 2)}')
print(f'R2 score: {np.round(r2_score(test, SES_test_pred_09), 2)}')

print('-'*55)
print('Double Exponential Smoothing (alpha = 0.16, beta = 0.1)')
print(f'MSE: {np.round(mean_squared_error(test, DES_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,DES_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, DES_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, DES_test_pred), 2)}')

print('-'*55)
print('Additive Holt-Winter Exponential Smoothing')
print(f'MSE: {np.round(mean_squared_error(test, HW_add_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,HW_add_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, HW_add_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, HW_add_test_pred), 2)}')

print('-'*55)
print('Multiplicative Holt-Winter Exponential Smoothing')
print(f'MSE: {np.round(mean_squared_error(test, HW_mul_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,HW_mul_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, HW_mul_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, HW_mul_test_pred), 2)}')

print('-'*55)
print(f'ARIMA {ARIMA_optimal[0][0]}')
print(f'MSE: {np.round(mean_squared_error(test, ARIMA_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,ARIMA_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, ARIMA_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, ARIMA_test_pred), 2)}')

print('-'*55)
print(f'SARIMA {SARIMA_optimal[0][0][0]},{SARIMA_optimal[0][0][1]}')
print(f'MSE: {np.round(mean_squared_error(test, SARIMA_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,SARIMA_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, SARIMA_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, SARIMA_test_pred), 2)}')

print('-'*55)
print('Prophet')
print(f'MSE: {np.round(mean_squared_error(test, PRO_test_pred), 2)}')
print(f'RMSE: {np.round(np.sqrt(mean_squared_error(test,PRO_test_pred)), 2)}')
print(f'MAE: {np.round(mean_absolute_error(test, PRO_test_pred), 2)}')
print(f'R2 score: {np.round(r2_score(test, PRO_test_pred), 2)}')
# Out:
# -------------------------------------------------------
# Moving Average (N = 5)
# MSE: 7745.58
# RMSE: 88.01
# MAE: 64.73
# R2 score: -0.27
# -------------------------------------------------------
# Simple Exponential Smoothing (alpha = 0.9)
# MSE: 8071.91
# RMSE: 89.84
# MAE: 78.17
# R2 score: -0.32
# -------------------------------------------------------
# Double Exponential Smoothing (alpha = 0.16, beta = 0.1)
# MSE: 4988.28
# RMSE: 70.63
# MAE: 57.25
# R2 score: 0.18
# -------------------------------------------------------
# Additive Holt-Winter Exponential Smoothing
# MSE: 1541.4
# RMSE: 39.26
# MAE: 31.79
# R2 score: 0.75
# -------------------------------------------------------
# Multiplicative Holt-Winter Exponential Smoothing
# MSE: 455.33
# RMSE: 21.34
# MAE: 17.46
# R2 score: 0.93
# -------------------------------------------------------
# ARIMA (1, 1, 2)
# MSE: 6828.67
# RMSE: 82.64
# MAE: 62.06
# R2 score: -0.12
# -------------------------------------------------------
# SARIMA (2, 1, 1),(2, 1, 2, 12)
# MSE: 33104915.1
# RMSE: 5753.69
# MAE: 5696.54
# R2 score: -5422.04
# -------------------------------------------------------
# Prophet
# MSE: 1710.13
# RMSE: 41.35
# MAE: 34.01
# R2 score: 0.72

# %% [markdown]
# ### 5. Case Study: 주가예측

# %%
def get_code(df, name):
    code = df.query("name=='{}'".format(name))['code'].to_string(index=False)
    code = code.strip()
    return code

# %%
code_data = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13', header=0)[0]
code_data # 2380 rows × 9
# Out:
#             회사명    종목코드               업종  \
# 0         DRB동일    4840         고무제품 제조업
# 1           DSR  155660      1차 비철금속 제조업
# 2            GS   78930           기타 금융업
# 3     HDC현대산업개발  294870           건물 건설업
# 4         KG케미칼    1390      기초 화학물질 제조업
# ...         ...     ...              ...
# 2572     카이바이오텍  446600          의약품 제조업
# 2573     코스텍시스템  169670    특수 목적용 기계 제조업
# 2574       타임기술  318660   소프트웨어 개발 및 공급업
# 2575   플럼라인생명과학  222670  자연과학 및 공학 연구개발업
# 2576   한국미라클피플사  331660      기타 화학제품 제조업
#
#                                                주요제품         상장일  결산월  \
# 0                 고무벨트(V벨트,콘베이어벨트,평벨트),프라스틱제품 제조,판매  1976-05-21  12월
# 1                                            합섬섬유로프  2013-05-15  12월
# 2                                       지주회사/부동산 임대  2004-08-05  12월
# 3                            외주주택, 자체공사, 일반건축, 토목 등  2018-06-12  12월
# 4                         콘크리트혼화제, 비료, 친환경농자재, 수처리제  1989-08-25  12월
# ...                                             ...         ...  ...
# 2572                                방사성 진단 및 치료 의약품  2022-12-23  12월
# 2573                             반도체 웨이퍼 이송장비, 본딩장비  2022-01-21  12월
# 2574  ILS(종합군수지원), IETM(전자식기술교범), CBT(전자식교보재), 기술번역  2021-06-24  12월
# 2575                               강아지암치료제,돼지DNA테라피  2015-07-28  12월
# 2576                                 은나노스텝, 닥터오렌지 등  2019-10-28  12월
#
#                          대표자명                        홈페이지     지역
# 0                         류영식         http://drbworld.com  부산광역시
# 1                         홍석빈          http://www.dsr.com  부산광역시
# 2          허태수, 홍순기 (각자 대표이사)                         NaN  서울특별시
# 3     최익훈, 정익희, 김회언 (각자 대표이사)      http://www.hdc-dvp.com  서울특별시
# 4                    곽정현, 김재익     http://www.kgchem.co.kr  울산광역시
# ...                       ...                         ...    ...
# 2572                      김영덕  http://www.kaibiotech.com/   전라북도
# 2573                      배준호     http://www.kosteks.com/    경기도
# 2574                      주양효         http://timett.co.kr   경상남도
# 2575                   김앤토니경태       http://www.plsdna.com  서울특별시
# 2576                      이호경       http://www.kmpc.co.kr    경기도
#
# [2577 rows x 9 columns]

# %%
code_data = code_data[['회사명', '종목코드']]
code_data = code_data.rename(columns={'회사명': 'name', '종목코드': 'code'})
code_data.code = code_data.code.map('{:06d}'.format)

# %%
# import yfinance as yfin
# yfin.pdr_override()

stock_code = get_code(code_data, 'LG전자')
stock_data = pdr.DataReader(stock_code, 'naver', start='2021-01-01', end='2023-02-09')


'''
Open: 장 시작 때 주가(시가)
High: 장 중 제일 높았던 주가(고가)
Low: 장 중 제일 낮았던 주가(저가)
Close: 장 닫을 때 주가(종가)
Volume: 주식 거래량

'''

stock_data
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2021-01-04  136500  144000  136500  142000  1868234
# 2021-01-05  139000  140000  137000  140000  1602818
# 2021-01-06  148500  150500  137000  137500  5283488
# 2021-01-07  139500  155000  137000  150000  9782722
# 2021-01-08  145000  151000  140500  147500  9472733
# ...            ...     ...     ...     ...      ...
# 2023-02-02  100100  101500   99000  100900   727164
# 2023-02-03  101300  102100  100200  100800   493356
# 2023-02-06  100900  102900  100000  101600   663779
# 2023-02-07  101800  103000  101300  102000   568693
# 2023-02-08  102500  108800  102200  107600  1806223
#
# [520 rows x 5 columns]

# %%
stock_data = stock_data['Close'].astype('int')
fig, ax = plt.subplots(figsize=(12, 6))
stock_data.plot(ax = ax)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
from sklearn.model_selection import train_test_split
stock_data_train, stock_data_test = train_test_split(stock_data, test_size=0.1, shuffle=False)

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))
fig.suptitle('Raw Data')
sm.graphics.tsa.plot_acf(stock_data_train.values.squeeze(), lags=40, ax=ax[0])
sm.graphics.tsa.plot_pacf(stock_data_train.values.squeeze(), lags=40, ax=ax[1]); # Modify not to generate graph twice

# %%
diff_stock_data_train = stock_data_train.copy()
diff_stock_data_train = diff_stock_data_train.diff()
diff_stock_data_train = diff_stock_data_train.dropna()
print('####### Raw Data #######')
print(stock_data_train)
print('### Differenced Data ###')
print(diff_stock_data_train)
# Out:
# ####### Raw Data #######
# Date
# 2021-01-04    142000
# 2021-01-05    140000
# 2021-01-06    137500
# 2021-01-07    150000
# 2021-01-08    147500
#                ...
# 2022-11-17     92900
# 2022-11-18     92000
# 2022-11-21     90100
# 2022-11-22     89500
# 2022-11-23     90200
# Name: Close, Length: 468, dtype: int64
# ### Differenced Data ###
# Date
# 2021-01-05    -2000.0
# 2021-01-06    -2500.0
# 2021-01-07    12500.0
# 2021-01-08    -2500.0
# 2021-01-11    -5500.0
#                ...
# 2022-11-17    -2700.0
# 2022-11-18     -900.0
# 2022-11-21    -1900.0
# 2022-11-22     -600.0
# 2022-11-23      700.0
# Name: Close, Length: 467, dtype: float64

# %%
# Differenced data plot

plt.figure(figsize=(12,8))
plt.subplot(211)
plt.plot(stock_data_train)
plt.legend(['Raw Data (Nonstationary)'])
plt.subplot(212)
plt.plot(diff_stock_data_train,'orange') # first difference (t - (t-1))
plt.legend(['Differenced Data (Stationary)'])
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))
fig.suptitle('Differenced Data')
sm.graphics.tsa.plot_acf(diff_stock_data_train.values.squeeze(), lags=40, ax=ax[0])
sm.graphics.tsa.plot_pacf(diff_stock_data_train.values.squeeze(), lags=40, ax=ax[1]); # Modify not to generate graph twice

# %%
# Parameter search 

auto_arima_model = auto_arima(stock_data_train, start_p=1, start_q=1,
                              max_p=3, max_q=3, seasonal=False,
                              d=1,
                              trace=True,
                              error_action='ignore',  
                              suppress_warnings=True, 
                              stepwise=False)
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=8936.893, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=8938.248, Time=0.02 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=8939.996, Time=0.03 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=8936.605, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=8938.123, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=8940.234, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=8937.719, Time=0.07 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=8937.760, Time=0.06 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=8939.653, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=8937.245, Time=0.05 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=8923.069, Time=0.16 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=8906.816, Time=0.24 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=8934.321, Time=0.05 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=8935.582, Time=0.05 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=8937.710, Time=0.10 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0] intercept
# Total fit time: 0.976 seconds

# %%
auto_arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  468
# Model:               SARIMAX(2, 1, 3)   Log Likelihood               -4446.408
# Date:                Wed, 08 Feb 2023   AIC                           8906.816
# Time:                        17:10:20   BIC                           8935.840
# Sample:                             0   HQIC                          8918.238
#                                 - 468
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   -131.0480    238.747     -0.549      0.583    -598.984     336.888
# ar.L1          0.3992      0.026     15.613      0.000       0.349       0.449
# ar.L2         -0.8783      0.025    -34.938      0.000      -0.928      -0.829
# ma.L1         -0.4229      0.041    -10.391      0.000      -0.503      -0.343
# ma.L2          0.9276      0.027     34.120      0.000       0.874       0.981
# ma.L3          0.0368      0.029      1.254      0.210      -0.021       0.094
# sigma2      1.041e+07      0.030   3.52e+08      0.000    1.04e+07    1.04e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.48   Jarque-Bera (JB):               238.56
# Prob(Q):                              0.49   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.26   Skew:                             0.82
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.28e+23. Standard errors may be unstable.
# """

# %%
AUTO_ARIMA_prediction = auto_arima_model.predict(len(stock_data_test), return_conf_int=True)
AUTO_ARIMA_test_pred = AUTO_ARIMA_prediction[0]
AUTO_ARIMA_test_ub = AUTO_ARIMA_prediction[1][:,0]
AUTO_ARIMA_test_lb = AUTO_ARIMA_prediction[1][:,1]
predict_index = list(stock_data_test.index)
predict_index[0]
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Timestamp('2022-11-24 00:00:00')

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(stock_data.index, stock_data.values, label = 'Passengers')
ax.vlines(datetime.datetime.strptime('2021-10-26','%Y-%m-%d'), 500, 1500, linestyle='--', color='r', label='Start of Forecast')
ax.plot(predict_index, AUTO_ARIMA_test_pred, label = 'Prediction')
ax.fill_between(predict_index, AUTO_ARIMA_test_lb, AUTO_ARIMA_test_ub, color = 'k', alpha = 0.1, label='0.95 Prediction Interval')
ax.legend(loc='upper left')
plt.suptitle(f'ARIMA {auto_arima_model.order},Prediction Results')
plt.show()

# %%
stock_data_train_prophet = stock_data_train.reset_index()
stock_data_train_prophet.columns = ['ds', 'y']

PRO_model = Prophet()
PRO_model.fit(stock_data_train_prophet)

stock_data_test_prophet = stock_data_test.reset_index()
stock_data_test_prophet.columns = ['ds', 'y']
stock_data_test_index = stock_data_test_prophet[['ds']]
# Out:
# 17:10:51 - cmdstanpy - INFO - Chain [1] start processing
# 17:10:51 - cmdstanpy - INFO - Chain [1] done processing

# %%
PRO_prediction = PRO_model.predict(stock_data_test_index)
PRO_prediction
# Out:
#            ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0  2022-11-24  81192.365046  73921.042597  92714.219960  81192.365046
# 1  2022-11-25  81096.910839  74015.229495  92037.270214  81096.910839
# 2  2022-11-28  80810.548219  73587.004574  92222.059994  80810.548219
# 3  2022-11-29  80715.094012  73907.149878  92918.463098  80715.094012
# 4  2022-11-30  80619.639805  73800.951784  92033.010772  80603.544623
# 5  2022-12-01  80524.185598  73205.192841  91261.513229  80479.308346
# 6  2022-12-02  80428.731391  73249.992351  92357.498828  80350.747579
# 7  2022-12-05  80142.368770  72778.628545  91870.304124  80030.209395
# 8  2022-12-06  80046.914563  72962.573325  91331.957085  79891.865576
# 9  2022-12-07  79951.460356  72666.769894  91792.798140  79759.060760
# 10 2022-12-08  79856.006149  73219.556889  91185.044342  79618.576771
# 11 2022-12-09  79760.551942  72002.912797  90544.127849  79478.829675
# 12 2022-12-12  79474.189321  72340.888963  90957.345155  79149.888060
# 13 2022-12-13  79378.735115  72394.451496  90414.658392  79002.372407
# 14 2022-12-14  79283.280908  72372.251497  90646.372663  78848.039806
# 15 2022-12-15  79187.826701  71763.749134  90512.776003  78688.653693
# 16 2022-12-16  79092.372494  72097.906625  89960.192559  78540.848454
# 17 2022-12-19  78806.009873  71427.198394  90321.458242  78173.690490
# 18 2022-12-20  78710.555666  71551.556121  90006.240585  78013.508467
# 19 2022-12-21  78615.101459  72073.730779  90455.444956  77830.501896
# 20 2022-12-22  78519.647252  71492.880459  89868.456217  77686.731770
# 21 2022-12-23  78424.193045  70946.857194  90032.966019  77501.478240
# 22 2022-12-26  78137.830424  71410.007490  89585.603108  77087.654172
# 23 2022-12-27  78042.376217  70831.761535  90535.976507  76895.682012
# 24 2022-12-28  77946.922010  70577.096263  89528.511619  76677.520173
# 25 2022-12-29  77851.467804  70253.882404  90117.703620  76516.291093
# 26 2023-01-02  77469.650976  69999.689736  89716.916669  76039.085591
# 27 2023-01-03  77374.196769  70208.255662  88802.980572  75847.355438
# 28 2023-01-04  77278.742562  70190.068740  89175.511773  75640.858405
# 29 2023-01-05  77183.288355  69990.385255  89232.492686  75450.136694
# 30 2023-01-06  77087.834148  69914.972140  88613.252640  75256.628790
# 31 2023-01-09  76801.471527  69666.569764  88970.018437  74843.113527
# 32 2023-01-10  76706.017320  69502.123648  88485.628978  74659.456606
# 33 2023-01-11  76610.563113  69369.481778  88904.823186  74460.252538
# 34 2023-01-12  76515.108906  69817.435567  88805.058465  74252.005579
# 35 2023-01-13  76419.654699  68682.050683  88108.019295  74046.032974
# 36 2023-01-16  76133.292079  68528.559434  88170.355912  73627.095700
# 37 2023-01-17  76037.837872  68187.224609  87511.248889  73414.207169
# 38 2023-01-18  75942.383665  68101.981818  87313.152413  73188.487089
# 39 2023-01-19  75846.929458  68560.639199  88714.444553  72982.415220
# 40 2023-01-20  75751.475251  67524.825398  86914.070342  72779.637201
# 41 2023-01-25  75274.204216  68505.196574  87552.805300  72196.912822
# 42 2023-01-26  75178.750009  66882.064952  87035.278877  71989.730035
# 43 2023-01-27  75083.295802  67232.878757  86944.673089  71763.957789
# 44 2023-01-30  74796.933182  67142.491705  86999.551403  71338.724463
# 45 2023-01-31  74701.478975  66192.228833  86834.282382  71104.926034
# 46 2023-02-01  74606.024768  66445.575635  87292.956339  70826.757004
# 47 2023-02-02  74510.570561  65588.622958  86892.395825  70591.478232
# 48 2023-02-03  74415.116354  65131.091282  86252.914573  70333.976658
# 49 2023-02-06  74128.753733  65890.980125  87435.481208  69890.152138
# 50 2023-02-07  74033.299526  66173.711592  87384.976771  69657.400322
# 51 2023-02-08  73937.845319  65232.794006  87023.694114  69438.969451
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0   81192.365046     2217.430350           2217.430350           2217.430350
# 1   81096.910839     2010.828784           2010.828784           2010.828784
# 2   80810.548219     2272.104251           2272.104251           2272.104251
# 3   80715.094012     2138.758831           2138.758831           2138.758831
# 4   80634.920838     2238.496128           2238.496128           2238.496128
# 5   80569.742591     2217.430350           2217.430350           2217.430350
# 6   80511.429255     2010.828784           2010.828784           2010.828784
# 7   80267.017965     2272.104251           2272.104251           2272.104251
# 8   80226.538327     2138.758831           2138.758831           2138.758831
# 9   80167.070850     2238.496128           2238.496128           2238.496128
# 10  80133.441960     2217.430350           2217.430350           2217.430350
# 11  80093.042693     2010.828784           2010.828784           2010.828784
# 12  79867.703825     2272.104251           2272.104251           2272.104251
# 13  79836.465193     2138.758831           2138.758831           2138.758831
# 14  79817.150689     2238.496128           2238.496128           2238.496128
# 15  79772.542226     2217.430350           2217.430350           2217.430350
# 16  79739.680572     2010.828784           2010.828784           2010.828784
# 17  79519.410031     2272.104251           2272.104251           2272.104251
# 18  79527.416849     2138.758831           2138.758831           2138.758831
# 19  79482.808574     2238.496128           2238.496128           2238.496128
# 20  79478.439898     2217.430350           2217.430350           2217.430350
# 21  79503.039184     2010.828784           2010.828784           2010.828784
# 22  79274.959320     2272.104251           2272.104251           2272.104251
# 23  79293.604707     2138.758831           2138.758831           2138.758831
# 24  79318.562556     2238.496128           2238.496128           2238.496128
# 25  79337.915364     2217.430350           2217.430350           2217.430350
# 26  79064.726133     2272.104251           2272.104251           2272.104251
# 27  79111.096218     2138.758831           2138.758831           2138.758831
# 28  79110.511185     2238.496128           2238.496128           2238.496128
# 29  79128.979414     2217.430350           2217.430350           2217.430350
# 30  79127.876079     2010.828784           2010.828784           2010.828784
# 31  78963.669179     2272.104251           2272.104251           2272.104251
# 32  78958.453699     2138.758831           2138.758831           2138.758831
# 33  78950.847313     2238.496128           2238.496128           2238.496128
# 34  78943.339514     2217.430350           2217.430350           2217.430350
# 35  78951.797944     2010.828784           2010.828784           2010.828784
# 36  78759.899412     2272.104251           2272.104251           2272.104251
# 37  78844.262037     2138.758831           2138.758831           2138.758831
# 38  78858.112160     2238.496128           2238.496128           2238.496128
# 39  78869.397978     2217.430350           2217.430350           2217.430350
# 40  78938.733563     2010.828784           2010.828784           2010.828784
# 41  78581.708631     2238.496128           2238.496128           2238.496128
# 42  78670.099244     2217.430350           2217.430350           2217.430350
# 43  78683.919528     2010.828784           2010.828784           2010.828784
# 44  78555.049725     2272.104251           2272.104251           2272.104251
# 45  78573.599492     2138.758831           2138.758831           2138.758831
# 46  78652.367623     2238.496128           2238.496128           2238.496128
# 47  78775.986015     2217.430350           2217.430350           2217.430350
# 48  78847.975865     2010.828784           2010.828784           2010.828784
# 49  78710.569966     2272.104251           2272.104251           2272.104251
# 50  78810.065925     2138.758831           2138.758831           2138.758831
# 51  78915.956727     2238.496128           2238.496128           2238.496128
#
#          weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0   2217.430350   2217.430350   2217.430350                   0.0
# 1   2010.828784   2010.828784   2010.828784                   0.0
# 2   2272.104251   2272.104251   2272.104251                   0.0
# 3   2138.758831   2138.758831   2138.758831                   0.0
# 4   2238.496128   2238.496128   2238.496128                   0.0
# 5   2217.430350   2217.430350   2217.430350                   0.0
# 6   2010.828784   2010.828784   2010.828784                   0.0
# 7   2272.104251   2272.104251   2272.104251                   0.0
# 8   2138.758831   2138.758831   2138.758831                   0.0
# 9   2238.496128   2238.496128   2238.496128                   0.0
# 10  2217.430350   2217.430350   2217.430350                   0.0
# 11  2010.828784   2010.828784   2010.828784                   0.0
# 12  2272.104251   2272.104251   2272.104251                   0.0
# 13  2138.758831   2138.758831   2138.758831                   0.0
# 14  2238.496128   2238.496128   2238.496128                   0.0
# 15  2217.430350   2217.430350   2217.430350                   0.0
# 16  2010.828784   2010.828784   2010.828784                   0.0
# 17  2272.104251   2272.104251   2272.104251                   0.0
# 18  2138.758831   2138.758831   2138.758831                   0.0
# 19  2238.496128   2238.496128   2238.496128                   0.0
# 20  2217.430350   2217.430350   2217.430350                   0.0
# 21  2010.828784   2010.828784   2010.828784                   0.0
# 22  2272.104251   2272.104251   2272.104251                   0.0
# 23  2138.758831   2138.758831   2138.758831                   0.0
# 24  2238.496128   2238.496128   2238.496128                   0.0
# 25  2217.430350   2217.430350   2217.430350                   0.0
# 26  2272.104251   2272.104251   2272.104251                   0.0
# 27  2138.758831   2138.758831   2138.758831                   0.0
# 28  2238.496128   2238.496128   2238.496128                   0.0
# 29  2217.430350   2217.430350   2217.430350                   0.0
# 30  2010.828784   2010.828784   2010.828784                   0.0
# 31  2272.104251   2272.104251   2272.104251                   0.0
# 32  2138.758831   2138.758831   2138.758831                   0.0
# 33  2238.496128   2238.496128   2238.496128                   0.0
# 34  2217.430350   2217.430350   2217.430350                   0.0
# 35  2010.828784   2010.828784   2010.828784                   0.0
# 36  2272.104251   2272.104251   2272.104251                   0.0
# 37  2138.758831   2138.758831   2138.758831                   0.0
# 38  2238.496128   2238.496128   2238.496128                   0.0
# 39  2217.430350   2217.430350   2217.430350                   0.0
# 40  2010.828784   2010.828784   2010.828784                   0.0
# 41  2238.496128   2238.496128   2238.496128                   0.0
# 42  2217.430350   2217.430350   2217.430350                   0.0
# 43  2010.828784   2010.828784   2010.828784                   0.0
# 44  2272.104251   2272.104251   2272.104251                   0.0
# 45  2138.758831   2138.758831   2138.758831                   0.0
# 46  2238.496128   2238.496128   2238.496128                   0.0
# 47  2217.430350   2217.430350   2217.430350                   0.0
# 48  2010.828784   2010.828784   2010.828784                   0.0
# 49  2272.104251   2272.104251   2272.104251                   0.0
# 50  2138.758831   2138.758831   2138.758831                   0.0
# 51  2238.496128   2238.496128   2238.496128                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                          0.0                         0.0  83409.795396
# 1                          0.0                         0.0  83107.739623
# 2                          0.0                         0.0  83082.652469
# 3                          0.0                         0.0  82853.852842
# 4                          0.0                         0.0  82858.135933
# 5                          0.0                         0.0  82741.615948
# 6                          0.0                         0.0  82439.560175
# 7                          0.0                         0.0  82414.473021
# 8                          0.0                         0.0  82185.673394
# 9                          0.0                         0.0  82189.956484
# 10                         0.0                         0.0  82073.436499
# 11                         0.0                         0.0  81771.380726
# 12                         0.0                         0.0  81746.293572
# 13                         0.0                         0.0  81517.493945
# 14                         0.0                         0.0  81521.777036
# 15                         0.0                         0.0  81405.257051
# 16                         0.0                         0.0  81103.201278
# 17                         0.0                         0.0  81078.114124
# 18                         0.0                         0.0  80849.314497
# 19                         0.0                         0.0  80853.597587
# 20                         0.0                         0.0  80737.077602
# 21                         0.0                         0.0  80435.021829
# 22                         0.0                         0.0  80409.934675
# 23                         0.0                         0.0  80181.135048
# 24                         0.0                         0.0  80185.418138
# 25                         0.0                         0.0  80068.898154
# 26                         0.0                         0.0  79741.755227
# 27                         0.0                         0.0  79512.955599
# 28                         0.0                         0.0  79517.238690
# 29                         0.0                         0.0  79400.718705
# 30                         0.0                         0.0  79098.662932
# 31                         0.0                         0.0  79073.575778
# 32                         0.0                         0.0  78844.776151
# 33                         0.0                         0.0  78849.059241
# 34                         0.0                         0.0  78732.539256
# 35                         0.0                         0.0  78430.483483
# 36                         0.0                         0.0  78405.396329
# 37                         0.0                         0.0  78176.596702
# 38                         0.0                         0.0  78180.879793
# 39                         0.0                         0.0  78064.359808
# 40                         0.0                         0.0  77762.304035
# 41                         0.0                         0.0  77512.700344
# 42                         0.0                         0.0  77396.180359
# 43                         0.0                         0.0  77094.124586
# 44                         0.0                         0.0  77069.037432
# 45                         0.0                         0.0  76840.237805
# 46                         0.0                         0.0  76844.520896
# 47                         0.0                         0.0  76728.000911
# 48                         0.0                         0.0  76425.945138
# 49                         0.0                         0.0  76400.857984
# 50                         0.0                         0.0  76172.058357
# 51                         0.0                         0.0  76176.341447

# %%
PRO_test_pred = PRO_prediction['yhat'].values
PRO_test_ub = PRO_prediction['yhat_upper'].values
PRO_test_lb = PRO_prediction['yhat_lower'].values
predict_index = list(stock_data_test.index)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(stock_data.index, stock_data.values, label = 'Passengers')
ax.vlines(datetime.datetime.strptime('2021-10-26','%Y-%m-%d'), 500, 1500, linestyle='--', color='r', label='Start of Forecast')
ax.plot(predict_index, PRO_test_pred, label = 'Prediction')
ax.fill_between(predict_index, PRO_test_lb, PRO_test_ub, color = 'k', alpha = 0.1, label='0.95 Prediction Interval')
ax.legend(loc='upper left')
plt.suptitle('Prophet Prediction Results')
plt.show()

# %% [markdown]
# # EOD
